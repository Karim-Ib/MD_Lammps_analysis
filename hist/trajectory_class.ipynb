# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import regex
from sklearn.neighbors import KDTree
from scipy.spatial import cKDTree
from scipy.integrate import simpson, trapezoid
import warnings, os

# %%
class Trajectory:
    '''
    Class to parse, manipulate and plot the lammps-trajectory objects.
    Takes one input argument 'file' which is the filepath of the .lammpstrj file to initialize
    - added functionality to also parse gromac trajectory .gro files.
    - TODO:: parse atom count from file instead of hardcode dummy -> only for gromac 
    '''

    def __init__(self, file, format='lammpstrj', scaled=1):
        '''
        init of trajectory class
        :param file: file path to get the trajectory from
        :param format: default "lammpstrj", optional "gromac" or "XDATCAR"
                NOTE: if you want to add more formats make sure to include the apropriate format_to_np() parsers 
                with the same output format as the included ones.
        '''
        self.file = file
        if format == 'lammpstrj':
            self.trajectory, self.box_dim, self.n_atoms = self.lammpstrj_to_np(scaled)
        if format == 'lammps_data':
            self.trajectory, self.box_dim, self.n_atoms = self.lammps_data_to_np(scaled)
        if format == 'gromac':
               self.trajectory, self.box_dim = self.gromac_to_np()
        if format == 'XDATCAR':
            self.trajectory, self.box_dim = self.xdatcar_to_np()
        self.n_snapshots = len(self.box_dim)
        self.box_size = 0
        self.get_box_size()
        
        if scaled == 0:
            self.scale_to_lammps(scaled)
            

        
        self.s1, self.s2 = self.split_species()
        self.indexlist = 0
        self.distance = 0
        self.ion_distance = 0

    def xdatcar_to_np(self):
        '''
        Method to parse vasp-xdatcar style formated trajectories
        :param file: string giving the XDATCAR file path
        :return: returns n_dim np array with the trajectory at each snapshot and a list of the current box dimensions
        ''' 

        snap_count = 0
        snap_lines = []
        n_atoms = 0

        with open(self.file) as f:
            for line_number, line in enumerate(f):

                if regex.match("Direct", line):
                    snap_count += 1
                    snap_lines.append(line_number + 1)
                    #print(snap_count)    
                if line_number == 6:
                    n_atoms = sum([int(i) for i in line.split()])
                    next

        atom_list = np.zeros((snap_count, n_atoms , 5))
        ind_list = [np.zeros(0) for _ in range(snap_count)]
        box_ind_list = [np.zeros(0) for _ in range(snap_count)]
        box_list = np.zeros((snap_count, 3, 3))
        box_lines = [i - 6 for i in snap_lines]
        for i in range(snap_count):
            ind_list[i] = np.arange(snap_lines[i], snap_lines[i] + n_atoms )
            box_ind_list[i] = np.arange(box_lines[i], box_lines[i] +3)



        snap_count = 0
        line_count = 0

        with open(self.file) as f:
            for line_number, line in enumerate(f):

                if any(line_number == box_ind_list[snap_count]):
                    #print(line.split())
                    box_list[snap_count, :]=np.array([float(i) for i in line.split()])

                if any(line_number == ind_list[snap_count]):
                    atom_list[snap_count, line_count, 2:] = np.array([float(i) for i in line.split()])
                    ### need way to distinguish O and H's in Vasps XDATCAR file
                    print(atom_list[snap_count, line_count, :])

                    line_count += 1
                if line_count == n_atoms:
                    snap_count += 1
                    line_count = 0
                    #print(snap_count)
                if line_number >= ind_list[-1][-1]:
                    break    
        return atom_list, box_list
    
    def lammps_data_to_np(self, scal=1):
        '''
        Method to parse lammps data-format trajectories
        :return: returns n_dim np array with the trajectory at each snapshot and a list of the current box dimensions

        NOTE: only works for single time-frame for now -> todo make it general, less hacky 
        '''

        ###find the number of snapshots we have and safe the corresponding line
        ###also finds the number of atoms to initialize n_dim array later
        particle_counter = 0
        n_atoms = []
        box_dim = []
        atom_list = []


        with open(self.file) as f:
            
            for snap, line in enumerate(f):


                if regex.match('[0-9]+ atoms', line):
                    print(line)
                    n_atoms.append(int(line.split()[0]))
                    print(n_atoms)
                    n_atoms = n_atoms[-1]
                    



                if snap > 4 and snap < 8:
                    box_dim.append(np.array([float(i) for i in line.split()[:2]]))
                    
                #todo: fix the regexp.match issue between windows and linux
                #n_atoms=384
                if snap > 16 and snap < 16 + n_atoms + 1:
                    atom_list.append(np.array([float(i) for i in line.split()[:5]]))


        # transform list of box information into useful square data format.

        temp = box_dim
        box_dim = []                             
        box_dim.append(np.stack(temp))
        temp = atom_list
        atom_list = np.stack(temp).reshape((1, 384, 5))
          
        print(atom_list.shape)

        ##renormalize coordinates using pbc if neccesary -> only if data is in scaled lammps coordinates [0,1]
        if scal == 1:


            temp = atom_list[:, :, 2:] >= 1
            atom_list[:, :, 2:][temp] = atom_list[:, :, 2:][temp] - 1
            temp = atom_list[:, :, 2:] < 0
            atom_list[:, :, 2:][temp] = atom_list[:, :, 2:][temp] + 1


        print(box_dim)
        return atom_list, box_dim, n_atoms



    def gromac_to_np(self):
        '''
        Method to parse gromac style formated trajectories
        :param file: string giving the lammpstrj file path
        :return: returns n_dim np array with the trajectory at each snapshot and a list of the current box dimensions
        '''


        snap_count = 0
        snap_lines = []
        n_atoms = 384   ###TODO: fix hard-code at some point

        with open(self.file) as f:
            for snap, line in enumerate(f):
                if regex.match('Generated', line.split()[0]):
                    snap_lines.append(snap + 2)
                    snap_count += 1

            atom_list = np.zeros((snap_count, n_atoms , 5))
            ind_list = [np.zeros(0) for _ in range(snap_count)]

            for i in range(snap_count):
                ind_list[i] = np.arange(snap_lines[i], snap_lines[i] + n_atoms )

        #print(ind_list)
        snap_count = 0
        line_count = 0
        box_dim = []
        with open(self.file) as f:
            for line_number, line in enumerate(f):

                if len(line.split()[:]) == 3:
                    box_dim.append(np.array([float(i) for i in line.split()[:]]))

                if any(line_number == ind_list[snap_count]):
                    if regex.match('OW1', line.split()[1]):
                        atom_list[snap_count, line_count, 1] = 1
                    if regex.match('HW2', line.split()[1]):
                        atom_list[snap_count, line_count, 1] = 2
                    if regex.match('HW3', line.split()[1]):
                        atom_list[snap_count, line_count, 1] = 2

                    atom_list[snap_count, line_count, 2:] = np.array([float(i) for i in line.split()[-3:]])
                    line_count += 1
                if line_count == n_atoms:
                    snap_count += 1
                    line_count = 0
                    print(snap_count)
                if line_number >= ind_list[-1][-1]:
                    break
        return atom_list, box_dim


    def lammpstrj_to_np(self, scal=1):
        '''
        function to parse lammstrj format files to extract trajectories and return them in useable numpy data structures.
        :param file: string giving the lammpstrj file path
        :return: returns n_dim np array with the trajectory at each snapshot
            '''

        # might be usefull to know total no. of lines later on
        n_lines = sum(1 for line in open(self.file))

        ###find the number of snapshots we have and safe the corresponding line
        ###also finds the number of atoms to initialize n_dim array later
        snap_count = 0
        box_lines = 0
        n_atoms = []
        snap_lines = []
        box_dim = []
        

        with open(self.file) as f:
            for snap, line in enumerate(f):
                if regex.match('ITEM: ATOMS id', line):
                    snap_lines.append(snap + 2)
                    snap_count += 1
                if regex.match('ITEM: NUMBER OF ATOMS', line):

                    n_atoms.append(int(next(f))) 
                if box_lines > 0:
                    box_lines -= 1
                    box_dim.append(np.array([float(i) for i in line.split()]))
                if regex.match('ITEM: BOX BOUNDS', line):
                    box_lines = 3
            # print(snap_count, snap_lines, n_atoms)
        
        #super hacky fix should work for now but todo:better solution
        n_atoms = n_atoms[0]
    
        # transform list of box information into useful square data format.
        n_box = len(box_dim)
        temp = box_dim
        box_dim = []
        for split in range(int(n_box / 3)):
            box_dim.append(np.stack((temp[(split * 3): (split * 3 + 3)])))

        for key, line in enumerate(snap_lines):
            snap_lines[key] = line + key
        ### initialize np.arry of size (no of timesteps, no of atoms, 3d+id+species)

        atom_list = np.zeros((snap_count, n_atoms, 5))
        ind_list = [np.zeros(0) for _ in range(snap_count)]

        for i in range(snap_count):
            ind_list[i] = np.arange(snap_lines[i], snap_lines[i] + n_atoms)
        # print(ind_list)
        snap_count = 0
        line_count = 0
        with open(self.file) as f:
            for line_number, line in enumerate(f):

                # if line_number in ind_list[snap_count]:
                if any(line_number == ind_list[snap_count]):
                    atom_list[snap_count, line_count, :] = np.array([float(i) for i in line.split()])
                    line_count += 1
                if line_count == n_atoms:
                    snap_count += 1
                    line_count = 0
                    print("Processing Snapshot:" + str(snap_count))
                if line_number >= ind_list[-1][-1]:
                    break
            for line in f:
                pass
            
        ##renormalize coordinates using pbc if neccesary    
        if scal == 1:
        
        
            temp = atom_list[:, :, 2:] >= 1
            atom_list[:, :, 2:][temp] = atom_list[:, :, 2:][temp] - 1
            temp = atom_list[:, :, 2:] < 0
            atom_list[:, :, 2:][temp] = atom_list[:, :, 2:][temp] + 1
            
            
        return atom_list, box_dim, n_atoms
    
    
    def scale_to_lammps(self, scal):
        for i in range(len(self.box_dim)):
                self.trajectory[i, :, 2] /= self.box_size[i][0]
                self.trajectory[i, :, 3] /= self.box_size[i][1]
                self.trajectory[i, :, 4] /= self.box_size[i][2]
        
        if scal == 0:
            temp = self.trajectory[:, :, 2:] >= 1
            self.trajectory[:, :, 2:][temp] = self.trajectory[:, :, 2:][temp] - 1
            temp = self.trajectory[:, :, 2:] < 0
            self.trajectory[:, :, 2:][temp] = self.trajectory[:, :, 2:][temp] + 1


    def get_box_size(self):
        '''
        function to determine the actual box size given the box_dimensions extracted from the lammpstrj file
        :return: list of box_size - lengths - (x, y, z) for each snapshot.
        '''

        self.box_size = [None] * self.n_snapshots

        for i in range(self.n_snapshots):
            self.box_size[i] = abs(self.box_dim[i][:, 0] - self.box_dim[i][:, 1])


    def split_species(self):
        '''
        routine to split a lammpstrj which is formated as a np.ndim array of the form (n_steps, n_particles, n_cols=5)
        into its seperate particles (assuming Water-Molecules)
        :return out_1, out_2: two output lists of 2d numpy arrays, one for each species
        '''

        n_snap, n_row, n_col = self.trajectory.shape

        out_1 = [np.zeros(0) for _ in range(n_snap)]
        out_2 = [np.zeros(0) for _ in range(n_snap)]

        for i in range(n_snap):
            out_1[i] = (self.trajectory[i, np.where(self.trajectory[i, :, 1] == 1), :]).reshape(-1, 5)
            out_2[i] = (self.trajectory[i, np.where(self.trajectory[i, :, 1] == 2), :]).reshape(-1, 5)

        return out_1, out_2

    def get_neighbour_KDT(self, species_1=None, species_2=None, mode='normal', snapshot=0):
        '''
        Routin using sklearns implementation of the KDTree datastructure for quick nearestneighbour search in O(log(n))
        compared to the naive O(N) approach
        :param species_1: 2D numpy array of the positions of particles from species1 (n_row, (index, species, x, y, z))
        :param species_2: 2D numpy array of the positions of particles from species2 (n_row, (index, species, x, y, z))
        :param mode: sets the handling of boundary conditions with default 'normal' meaning no boundary condition
                    optional mode ['pbc']
        :param snapshot: specifies which snapshot we are looking at, default value is 0
        :return: ind_out np.array of the nearest neighbour indices of species1 found in species2, dist_out np.array of
                the euclidean distance
        '''

        #workaround to set instance atributes as default argument
        if species_1 is None:
            species_1 = self.s1 
        if species_2 is None:
            species_2 = self.s2 
        #if species_1 or species_2 == 0:
            #raise ValueError('set self.s1 or self.s2 first or pass required arguments')
        try:
            #print(species_1.shape)
            if mode == 'normal':
                tree = cKDTree(data=species_2[:, 2:] * self.box_size[snapshot], leafsize=species_2.shape[0])
            if mode == 'pbc':
                tree = cKDTree(data=species_2[:, 2:] * self.box_size[snapshot],
                               leafsize=species_2.shape[0], boxsize=self.box_size[snapshot])

            n_query = species_1.shape[0]
            ind_out = np.zeros(n_query)
            dist_out = np.zeros(n_query)
            for i in range(n_query):
                dist_out[i], ind_out[i] = tree.query((species_1[i, 2:] * self.box_size[snapshot]).reshape(1, -1), k=1)
                
        except (AttributeError, TypeError) as error:

            print("Atribute Error occured(recieved list instead of numpy array) using first element of list instead")
            species_1 = species_1[snapshot] 
            species_2 = species_2[snapshot] 

            if mode == 'normal':
                tree = cKDTree(data=species_2[:, 2:] * (self.box_size[snapshot]).reshape(1, -1), leafsize=species_2.shape[0])
            if mode == 'pbc':
                tree = cKDTree(data=species_2[:, 2:] * (self.box_size[snapshot]).reshape(1, -1), leafsize=species_2.shape[0], boxsize=self.box_size[snapshot])

            n_query = species_1.shape[0]
            ind_out = np.zeros(n_query)
            dist_out = np.zeros(n_query)
            for i in range(n_query):
                dist_out[i], ind_out[i] = tree.query((species_1[i, 2:]).reshape(1, -1) * (self.box_size[snapshot]).reshape(1, -1), k=1)

        return ind_out, dist_out

    def get_neighbour_naive(self, species_1=None, species_2=None, mode='normal', snapshot=0):
        '''
        Naive approach in calculating the nearest neighbour in linear time O(N) no optimizations done!
        :param species_1: 2D numpy array of the positions of particles from species1 (n_row, (index, species, x, y, z))
        :param species_2: 2D numpy array of the positions of particles from species2 (n_row, (index, species, x, y, z))
        :param mode: sets the handling of boundary conditions with default 'normal' meaning no boundary condition
                    optional mode ['pbc']
        :param snapshot: specifies which snapshot we are looking at, default value is 0
        :return: ind_out np.array of the nearest neighbour indices of species1 found in species2, dist_out np.array of
                the euclidean distance
        '''

        def get_distance(x, y, mode='normal', img=snapshot):
            '''
            wraper for np norm function to get euclidean metric
            :param x:
            :param y:
            :param mode: sets the mode for distance calculation
            :param img: specifies the image we are looking at, used to get the correct box size for PBC
            :return:
            '''

            if mode == 'normal':
                return np.linalg.norm(x-y)
            if mode == 'pbc':
                box = self.box_size[img]
                dist = x - y

                if dist[0] >= (box[0] / 2):
                    dist[0] -= box[0]
                if dist[0] < (-box[0] / 2):
                    dist[0] += box[0]

                if dist[1] >= (box[1] / 2):
                    dist[1] -= box[1]
                if dist[1] < (-box[1] / 2):
                    dist[1] += box[1]

                if dist[2] >= (box[2] / 2):
                    dist[2] -= box[2]
                if dist[2] < (-box[2] / 2):
                    dist[2] += box[2]

                return np.sqrt(np.sum(dist**2))
            else:
                raise ValueError(f'mode {mode} unknown please use either \'normal\' or \'pbc\'')

        if species_1 is None:
            species_1 = self.s1 * self.box_size
        if species_2 is None:
            species_2 = self.s2 * self.box_size
        try:
            n_row_1 = species_1.shape[0]
            n_row_2 = species_2.shape[0]

            distance_matrix = np.zeros((n_row_1, n_row_2))
            distances = np.zeros(n_row_1)
            index = np.zeros(n_row_1, dtype='int32')

            for H in range(n_row_1):
                for O in range(n_row_2):
                    distance_matrix[H, O] = get_distance(species_1[H, 2:], species_2[O, 2:], mode)

                index[H] = np.argmin(distance_matrix[H, :])
                distances[H] = distance_matrix[H, index[H]]

        except AttributeError:

            print("Atribute Error occured(recieved list instead of numpy array) using indexed element of list instead")
            species_1 = species_1[snapshot] * self.box_size[snapshot]
            species_2 = species_2[snapshot] * self.box_size[snapshot]
            n_row_1 = species_1.shape[0]
            n_row_2 = species_2.shape[0]

            distance_matrix = np.zeros((n_row_1, n_row_2))
            distances = np.zeros(n_row_1)
            index = np.zeros(n_row_1, dtype='int32')

            for H in range(n_row_1):
                for O in range(n_row_2):
                    distance_matrix[H, O] = get_distance(species_1[H, 2:], species_2[O, 2:], mode)

                index[H] = np.argmin(distance_matrix[H, :])
                #print(index[H], H)
                distances[H] = distance_matrix[H, index[H]]

        return index, distances

    def get_ion_distance(self):
        '''
        Method to calculate the euclidean distance between the two ions at each timestep, based on the
        distance of the OH- , H3O+ Oxygen Atoms. 
        :return: array [n_snap, (x1, y1, z1, x2, y2, z2, distance)]
        '''
        
        #note -> find solution to not copy get_distance function code into each method 
        #-> maybe make it a method by itselfe
        def get_distance(x, y, mode='pbc'):
            '''
            wraper for np norm function to get euclidean metric
            :param x:
            :param y:
            :param mode: sets the mode for distance calculation
            :param img: specifies the image we are looking at, used to get the correct box size for PBC
            :return:
            '''

            if mode == 'normal':
                return np.linalg.norm(x-y)
            if mode == 'pbc':
                box = [1, 1, 1] ##using scaled lammps coordinates
                dist = x - y
                if dist[0] >= (box[0] / 2):
                    dist[0] -= box[0]
                if dist[0] < (-box[0] / 2):
                    dist[0] += box[0]

                if dist[1] >= (box[1] / 2):
                    dist[1] -= box[1]
                if dist[1] < (-box[1] / 2):
                    dist[1] += box[1]

                if dist[2] >= (box[2] / 2):
                    dist[2] -= box[2]
                if dist[2] < (-box[2] / 2):
                    dist[2] += box[2]

                return np.sqrt(np.sum(dist**2))
            else:
                raise ValueError(f'mode {mode} unknown please use either \'normal\' or \'pbc\'')

        
        self.ion_distance = np.zeros((self.n_snapshots, 8))
        #OH_id = None
        #H3O_id = None
        #step 1 get particle ids of the two ion oxygens
            #step 1.1 detect ions 

        for i in range(self.n_snapshots): 
            
            OH_id = None
            H3O_id = None
            
            #note: find nearest O atom for each H atom
            indexlist_group, _ = self.get_neighbour_KDT(species_1=self.s1[i], 
                                                        species_2=self.s2[i], mode="pbc", snapshot=0) 

            #note: find he  number of  occourence of O atoms for which it is the nearest to an H atom. 
            #-> for H2O each O atom will count twice, for each H3O+ each O atom will count 3 times and so on.
            temp = [None]*self.s2[i].shape[0]
            for O_atom in  range(self.s2[i].shape[0]): 
                temp[O_atom] = np.append(np.argwhere(indexlist_group == O_atom), O_atom)

            #print(temp)
            #check how often each O atom counted -> molecules formation  OH- = 1 time H3O+  3 Times  H2O 2 times. 
            for ind, _list in enumerate(temp):
                #print(list)

                if len(_list) == 2:
                    OH_id = _list[-1]
                if len(_list) == 4:
                    H3O_id = _list[-1]
                else:
                    pass

            try:
                if OH_id is None or H3O_id is None:
                    raise ValueError("Either OH or H3O index was not found")




                temp = get_distance(self.trajectory[i, OH_id, 2:], self.trajectory[i, H3O_id, 2:])

                self.ion_distance[i, :] = np.array([i] + self.trajectory[i, OH_id, 2:].tolist() \
                                                      + self.trajectory[i, H3O_id, 2:].tolist() + [temp])
            except ValueError:
                self.ion_distance[i, :] = np.array([i] + [0, 0, 0] \
                                                      + [0, 0, 0] + [0])

        return self.ion_distance
    
    
    def get_hydrogen_bonds(self):
        
        
        return None
    
    
    def get_water_hist(self, index_list=None):
        '''
        Quick Wraperfunction for pyplot OOP APi to draw a histogram of H-Bond distribution
        :param index_list: list of indexes for NN of the H-Atoms
        :return: Plot of the Histogram
        '''

        if index_list is None:
            index_list = self.indexlist
        #if index_list == 0:
            #raise ValueError('set self.indexlist first or pass required arguments')

        fig = plt.figure()
        ax1 = fig.add_subplot(1, 1, 1)

        ax1.yaxis.grid(alpha=0.7, linestyle="dashed", linewidth=1.5)
        ax1.set_ylabel("number of H Bonds")
        ax1.set_xlabel("index of O Atom")
        ax1.set_title("Histogram of Water Species")
        ax1.xaxis.set_ticks_position('none')
        ax1.yaxis.set_ticks_position('none')
        h, _, _ = ax1.hist(index_list, bins=np.arange(min(index_list), max(index_list) + 1, 1),
                           histtype='bar', alpha=0.8, color="purple")
        plt.show()
        plt.hist(h, bins=np.arange(min(h), max(h) + 1, 1),
                 histtype='bar', alpha=0.8, color="purple", density=True)
        plt.xlabel('number of H bonds')
        plt.ylabel('frequency')
        plt.title('Distribution of H-Bonds')
        plt.show()
        return


    def get_displace(self, snapshot = 0, id = None, distance=0.05, eps=0.01, dp_factor = 0.99,
                     path=None, num_traj=None):
        '''
        :param snapshot: index of the snapshot at which the displacement should happen
        :param id: id of the reference oxygen if none is given one will be picked at random
        :param distance: distance to where we want to displace to (searching for an oxygen
         particle in that radius)
        :param eps: dr at which we still accept an oxygen
        :param dp_factor: factor with which the hydrogens coordinates differ to its reference, 
                NOTE will get replaced by a collision detection method 
        :param path: Optional path to safe the file in, otherwise it will be safed in the current directory
        :param name: Optional file name, otherwise it will be called "water.data"
        :param num_traj: Optional number of different trajectories to be generated
        :return: trajectory with one Oxygen removed and one Hydrogen displaced
        '''
            
            
        def get_distance(x, y, mode='pbc'):
            '''
            wraper for np norm function to get euclidean metric
            :param x:
            :param y:
            :param mode: sets the mode for distance calculation
            :param img: specifies the image we are looking at, used to get the correct box size for PBC
            :return:
            '''

            if mode == 'normal':
                return np.linalg.norm(x-y)
            if mode == 'pbc':
                box = [1, 1, 1] ##using scaled lammps coordinates
                dist = x - y
                if dist[0] >= (box[0] / 2):
                    dist[0] -= box[0]
                if dist[0] < (-box[0] / 2):
                    dist[0] += box[0]

                if dist[1] >= (box[1] / 2):
                    dist[1] -= box[1]
                if dist[1] < (-box[1] / 2):
                    dist[1] += box[1]

                if dist[2] >= (box[2] / 2):
                    dist[2] -= box[2]
                if dist[2] < (-box[2] / 2):
                    dist[2] += box[2]

                return np.sqrt(np.sum(dist**2))
            else:
                raise ValueError(f'mode {mode} unknown please use either \'normal\' or \'pbc\'')
                
        def get_displaced_H(H_displace, H_pair, reference_O):
            '''
            helper function to find the coordinates of the displaced H Atom by finding the midpoint between the Bondingatoms of
            the reference O atom and then mirroring this point in space, while making sure the distance between the displaced H 
            and the reference O is smaler then the distance fo the O to its closest bonding H
            '''
        
            minimum_distance = np.min([get_distance(H_pair[0], reference_O), get_distance(H_pair[1], reference_O)])
            midpoint = (H_pair[0] + H_pair[1]) / 2
            mid_vector = midpoint - reference_O
            
            
            new_H = midpoint - 2 * mid_vector
            while (get_distance(new_H, reference_O) < 1.1*minimum_distance) :
                new_H -= 0.05*mid_vector 
                if get_distance(new_H, reference_O) >= 1.2*minimum_distance:
                    return new_H
            return new_H
        
        
        if path is None:
            water_file = "water.data"
        else:
            water_file = path + "water.data"

            
        if num_traj is None:
            
            if id is None:
                id = np.random.randint(0, len(self.s2[0]))
            
            
            traj = self.trajectory[snapshot]
            O_list = self.s2[snapshot]
            H_list = self.s1[snapshot]
            O_list = O_list[:, 2:]
            H_list = H_list[:, 2:]
            reference_O = O_list[id, :]
            reference_H = H_list[np.argwhere(self.indexlist == id).reshape(-1), :]
            distances = []


            for i in range(len(O_list)):
                temp = get_distance(reference_O, O_list[i, :])
                
                if temp == 0.0:
                    continue 
                
                print(temp)
                
                

                if (temp <= (distance + eps)) and (temp >= (distance - eps)):
                    displace_H = H_list[np.argwhere(self.indexlist == i)[0], :]


                    ### displace the H towards the reference O
                    print("displace")
                    displace_H = get_displaced_H(displace_H, reference_H, reference_O)


                    #O_list = np.delete(O_list, i, axis=0) -> if we want to remove an O (not sure if we do?)

                    #update the hydrogen list with the new displaced coordinates
                    H_list[np.argwhere(self.indexlist == i)[0], :] = displace_H

                            ##renormalize coordinates using pbc if neccesary    
                    temp = H_list[:, :] >= 1
                    H_list[:, :][temp] = H_list[:, :][temp] - 1
                    temp = H_list[:, :] < 0
                    H_list[:, :][temp] = H_list[:, :][temp] + 1

                    with open(water_file, "a") as input_traj:
                        input_traj.write('translated LAMMPS data file via gromacsconf\n')
                        input_traj.write('\n')
                        input_traj.write(f'       {self.n_atoms}  atoms\n')
                        input_traj.write('           2  atom types\n')
                        input_traj.write('\n')
                        input_traj.write(f'   0.00000000       {self.box_size[snapshot][0]}       xlo xhi\n')
                        input_traj.write(f'   0.00000000       {self.box_size[snapshot][1]}       ylo yhi\n')
                        input_traj.write(f'   0.00000000       {self.box_size[snapshot][2]}       zlo zhi\n')
                        input_traj.write(f'   0.00000000       0.00000000       0.00000000      xy xz yz\n')
                        input_traj.write('\n')
                        input_traj.write(' Masses\n')
                        input_traj.write('\n')
                        input_traj.write('           1   1.00794005\n')
                        input_traj.write('           2   15.9994001\n')
                        input_traj.write('\n')
                        input_traj.write(' Atoms\n')
                        input_traj.write('\n')

                        for H_ind in range(H_list.shape[0]):
                            input_traj.write(f'{H_ind + 1} 1 {H_list[H_ind, 0]*self.box_size[snapshot][0]} {H_list[H_ind, 1]*self.box_size[snapshot][1]} {H_list[H_ind, 2]*self.box_size[snapshot][2]}')
                            input_traj.write('\n')
                        for O_ind in range(O_list.shape[0]):
                            input_traj.write(f'{O_ind + 1 + H_list.shape[0] } 2 {O_list[O_ind, 0]*self.box_size[snapshot][0]} {O_list[O_ind, 1]*self.box_size[snapshot][1]} {O_list[O_ind, 2]*self.box_size[snapshot][2]}')
                            input_traj.write('\n')


                    return print("trajectory saved as water.data")

                else:
                    distances.append(temp)
                    print("distance too far next O")
                
        if num_traj is not None:
            
            if isinstance(num_traj, int):
                pass
            else:
                num_traj = int(num_traj)
                warnings.warn("num_traj is not an integer, it will be converted. please check format")
                
            
            
            
            for copy in range(num_traj):
                
                if id is None:
                    id = np.random.randint(0, len(self.s2[0]))
            
            
                traj = self.trajectory[snapshot]
                O_list = self.s2[snapshot]
                H_list = self.s1[snapshot]
                O_list = O_list[:, 2:]
                H_list = H_list[:, 2:]
                reference_O = O_list[id, :]
                reference_H = H_list[np.argwhere(self.indexlist == id).reshape(-1), :]
                distances = []


                for i in range(len(O_list)):
                    temp = get_distance(reference_O, O_list[i, :])
                    
                    if temp == 0.0:
                        continue 
                    
                    print(temp)
                    


                    if (temp <= distance + eps) and (temp >= distance - eps):
                        displace_H = H_list[np.argwhere(self.indexlist == i)[0], :]


                        ### displace the H towards the reference O
                        print("displace")
                        displace_H = get_displaced_H(displace_H, reference_H, reference_O)


                        #O_list = np.delete(O_list, i, axis=0) -> if we want to remove an O (not sure if we do?)

                        #update the hydrogen list with the new displaced coordinates
                        H_list[np.argwhere(self.indexlist == i)[0], :] = displace_H

                        ##renormalize coordinates using pbc if neccesary    
                        temp = H_list[:, :] >= 1
                        H_list[:, :][temp] = H_list[:, :][temp] - 1
                        temp = H_list[:, :] < 0
                        H_list[:, :][temp] = H_list[:, :][temp] + 1
                        water_file = water_file + "_" + str(copy)
                        
                        with open(water_file, "a") as input_traj:
                            input_traj.write('translated LAMMPS data file via gromacsconf\n')
                            input_traj.write('\n')
                            input_traj.write(f'       {self.n_atoms}  atoms\n')
                            input_traj.write('           2  atom types\n')
                            input_traj.write('\n')
                            input_traj.write(f'   0.00000000       {self.box_size[snapshot][0]}       xlo xhi\n')
                            input_traj.write(f'   0.00000000       {self.box_size[snapshot][1]}       ylo yhi\n')
                            input_traj.write(f'   0.00000000       {self.box_size[snapshot][2]}       zlo zhi\n')
                            input_traj.write(f'   0.00000000       0.00000000       0.00000000      xy xz yz\n')
                            input_traj.write('\n')
                            input_traj.write(' Masses\n')
                            input_traj.write('\n')
                            input_traj.write('           1   1.00794005\n')
                            input_traj.write('           2   15.9994001\n')
                            input_traj.write('\n')
                            input_traj.write(' Atoms\n')
                            input_traj.write('\n')

                            for H_ind in range(H_list.shape[0]):
                                input_traj.write(f'{H_ind + 1} 1 {H_list[H_ind, 0]*self.box_size[snapshot][0]} {H_list[H_ind, 1]*self.box_size[snapshot][1]} {H_list[H_ind, 2]*self.box_size[snapshot][2]}')
                                input_traj.write('\n')
                            for O_ind in range(O_list.shape[0]):
                                input_traj.write(f'{O_ind + 1 + H_list.shape[0] } 2 {O_list[O_ind, 0]*self.box_size[snapshot][0]} {O_list[O_ind, 1]*self.box_size[snapshot][1]} {O_list[O_ind, 2]*self.box_size[snapshot][2]}')
                                input_traj.write('\n')


                        print(f"trajectory saved as water_{copy}.data")

                    else:
                        distances.append(temp)
                        print("distance too far next O")
    
    
    def cut_snapshot(self, snapshot=0, path=None):
        '''
        Method to remove a single time-frame from an entire trajectory for usage as an input for a new md run.
        :param snapshot: the frame at which point in time should be cut, default=0
        :param path: path to where the file should be saved to, default=None -> CWD
        '''
                    
        traj = self.trajectory[snapshot]
        O_list = self.s2[snapshot]
        H_list = self.s1[snapshot]
        O_list = O_list[:, 2:]
        H_list = H_list[:, 2:]
        
        if path is not None:
            water_file = path + "traj_cut_out.data"
        else:
            water_file = "traj_cut_out.data"

                        
        with open(water_file, "a") as input_traj:
            input_traj.write('translated LAMMPS data file via gromacsconf\n')
            input_traj.write('\n')
            input_traj.write(f'       {self.n_atoms}  atoms\n')
            input_traj.write('           2  atom types\n')
            input_traj.write('\n')
            input_traj.write(f'   0.00000000       {self.box_size[snapshot][0]}       xlo xhi\n')
            input_traj.write(f'   0.00000000       {self.box_size[snapshot][1]}       ylo yhi\n')
            input_traj.write(f'   0.00000000       {self.box_size[snapshot][2]}       zlo zhi\n')
            input_traj.write(f'   0.00000000       0.00000000       0.00000000      xy xz yz\n')
            input_traj.write('\n')
            input_traj.write(' Masses\n')
            input_traj.write('\n')
            input_traj.write('           1   1.00794005\n')
            input_traj.write('           2   15.9994001\n')
            input_traj.write('\n')
            input_traj.write(' Atoms\n')
            input_traj.write('\n')

            for H_ind in range(H_list.shape[0]):
                input_traj.write(f'{H_ind + 1} 1 {H_list[H_ind, 0]*self.box_size[snapshot][0]} {H_list[H_ind, 1]*self.box_size[snapshot][1]} {H_list[H_ind, 2]*self.box_size[snapshot][2]}')
                input_traj.write('\n')
            for O_ind in range(O_list.shape[0]):
                input_traj.write(f'{O_ind + 1 + H_list.shape[0] } 2 {O_list[O_ind, 0]*self.box_size[snapshot][0]} {O_list[O_ind, 1]*self.box_size[snapshot][1]} {O_list[O_ind, 2]*self.box_size[snapshot][2]}')
                input_traj.write('\n')


                        
                        
    def remove_atoms(self, N=1, snap=0, atom_id=None, format_out="lammps"):
        '''
        Method to remove molecules from a given trajectory. New trajectory will be safed as "reduced_water.format"
        in the current folder. For N=0 this can be used to simply change the format i.e lammps>XDATCAR
        :param N: number of atoms to remove
        :param snap: from which snapshot of the original trajectory are the molecules to be removed
        :param atom_id: default=None, takes an np.array of the oxygen which is to be removed with its matching 
                        hydrogens. If not passed atoms will be taken at random
        '''


        O_list = self.s2[snap]
        H_list = self.s1[snap]
        print(O_list.shape, H_list.shape)
        to_remove_H_ind = np.empty(0, dtype=int)
        to_remove_O_ind = np.empty(0, dtype=int)
        atom_id = np.random.choice(len(O_list), size=N, replace=False)

        NN_list, _ = self.get_neighbour_KDT(mode='pbc', snapshot=snap)
        NN_list = np.rint(NN_list).astype(int)

        for i in range(N):
            

            to_remove_H_ind = np.append(to_remove_H_ind, np.argwhere(NN_list == atom_id[i])) 
            to_remove_O_ind = np.append(to_remove_O_ind, NN_list[to_remove_H_ind])
            


            #remember axis=0 -> rows
        
        O_list = np.delete(O_list, to_remove_O_ind, axis=0)
        H_list = np.delete(H_list, to_remove_H_ind, axis=0)
        print(O_list.shape, H_list.shape)

        if format_out == "lammps":

            def write_lammpstrj(atoms, ts=0, snapshot=0):
                with open("reduced_water.lammpstrj", "w") as group_traj:
                    group_traj.write('ITEM: TIMESTEP\n')
                    group_traj.write(f'{snapshot * ts}\n')
                    group_traj.write("ITEM: NUMBER OF ATOMS\n")
                    group_traj.write(str(self.n_atoms-3*N)+"\n")
                    #group_traj.write("ITEM: BOX BOUNDS xy xz yz pp pp pp\n")
                    group_traj.write("ITEM: BOX BOUNDS pp pp pp\n")
                    for i in range(3):
                        temp = " ".join(map(str, self.box_dim[snapshot][i, :]))
                        group_traj.write(f'{temp}\n')

                    group_traj.write("ITEM: ATOMS id type xs ys zs\n")

                    for i in range(atoms.shape[0]):
                        temp = atoms[i, :]
                        temp = " ".join(map(str, temp))
                        group_traj.write(f'{temp}\n')

                return

            write_lammpstrj(np.vstack((O_list, H_list)), snapshot=snap)
            return

        elif format_out == "XDATCAR":
            def write_XDATCAR(atoms, ts=0, snapshot=0, n_O=O_list.shape[0], n_H=H_list.shape[0]):
                with open("reduced_XDATCAR", "w") as group_traj:
                    group_traj.write(f'unknown system\n')
                    group_traj.write(f'           1\n')
                    group_traj.write(f'    {np.round(self.box_size[snapshot][0], 6)}    0.000000    0.000000\n')
                    group_traj.write(f'     0.000000   {np.round(self.box_size[snapshot][1], 6)}    0.000000\n')
                    group_traj.write(f'     0.000000    0.000000   {np.round(self.box_size[snapshot][1], 6)}\n')
                    group_traj.write("    O    H\n")
                    group_traj.write(f'    {n_O}   {n_H}\n')
                    group_traj.write(f'Direct configuration=     1\n')
                    for i in range(atoms.shape[0]):
                        temp = atoms[i, 2:]
                        temp = " ".join(map(str, temp))
                        group_traj.write(f'{temp}\n')

                return
            write_XDATCAR(np.vstack((O_list, H_list)), snapshot=snap)
        
        
        
        

        elif format_out == "gromac":
            warnings.warn("Foarmat gromac currently not supported")
            return

        else:
            warnings.warn("not supported format_out please check documentation for viable formats")
            return

        

    def group_molecules(self, timestep=5000, path=None):
        '''
        method to group nearest neighbours back to molecules to track their trajectory in time
        :return: lammpstraj file readable by common MD visualizer like ovito
        '''

        if path is not None:
             new_traj = open(path+'grouped_water.lammpstrj', "w")
        else:
            new_traj = open('grouped_water.lammpstrj', "w")
            
        new_traj.close()


        def write_lammpstrj(molecules, ts=timestep, snapshot=0, _dir=path):
            if _dir is not None:
                with open(_dir+"grouped_water.lammpstrj", "a") as group_traj:
                    group_traj.write('ITEM: TIMESTEP\n')
                    group_traj.write(f'{snapshot * ts}\n')
                    group_traj.write("ITEM: NUMBER OF ATOMS\n")
                    group_traj.write(str(self.n_atoms)+"\n")
                    #group_traj.write("ITEM: BOX BOUNDS xy xz yz pp pp pp\n")
                    group_traj.write("ITEM: BOX BOUNDS pp pp pp\n")
                    for i in range(3):
                        temp = " ".join(map(str, self.box_dim[snapshot][i, :]))
                        group_traj.write(temp+"\n")

                    group_traj.write("ITEM: ATOMS id type xs ys zs\n")

                    for ind, list in enumerate(molecules):
                        if len(list) == 1:              #only O atom
                            for index in list:
                                temp = self.s2[snapshot][index, :]
                                temp[1] = 1
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                        if len(list) == 2:
                            for index in list[:-1]:     #index all the H atoms
                                temp = self.s1[snapshot][index, :]
                                temp[1] = 2
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                            temp = self.s2[snapshot][list[-1], :]         #write the O atom by hand
                            temp[1] = 2
                            temp = " ".join(map(str, temp))
                            group_traj.write(temp+"\n")
                        if len(list) == 3:
                            for index in list[:-1]:
                                #print(type(index))
                                temp = self.s1[snapshot][index, :]
                                temp[1] = 3
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                            temp = self.s2[snapshot][list[-1], :]
                            temp[1] = 3
                            temp = " ".join(map(str, temp))
                            group_traj.write(temp+"\n")
                        if len(list) == 4:
                            for index in list[:-1]:
                                temp = self.s1[snapshot][index, :]
                                temp[1] = 4
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                            temp = self.s2[snapshot][list[-1], :]
                            temp[1] = 4
                            temp = " ".join(map(str, temp))
                            group_traj.write(temp+"\n")

                        if len(list) == 5:
                            for index in list[:-1]:
                                temp = self.s1[snapshot][index, :]
                                temp[1] = 5
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                            temp = self.s2[snapshot][list[-1], :]
                            temp[1] = 5
                            temp = " ".join(map(str, temp))
                            group_traj.write(temp+"\n")
                return
            else:
                with open("grouped_water.lammpstrj", "a") as group_traj:
                    group_traj.write('ITEM: TIMESTEP\n')
                    group_traj.write(f'{snapshot * ts}\n')
                    group_traj.write("ITEM: NUMBER OF ATOMS\n")
                    group_traj.write(str(self.n_atoms)+"\n")
                    #group_traj.write("ITEM: BOX BOUNDS xy xz yz pp pp pp\n")
                    group_traj.write("ITEM: BOX BOUNDS pp pp pp\n")
                    for i in range(3):
                        temp = " ".join(map(str, self.box_dim[snapshot][i, :]))
                        group_traj.write(temp+"\n")

                    group_traj.write("ITEM: ATOMS id type xs ys zs\n")

                    for ind, list in enumerate(molecules):
                        if len(list) == 1:              #only O atom
                            for index in list:
                                temp = self.s2[snapshot][index, :]
                                temp[1] = 1
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                        if len(list) == 2:
                            for index in list[:-1]:     #index all the H atoms
                                temp = self.s1[snapshot][index, :]
                                temp[1] = 2
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                            temp = self.s2[snapshot][list[-1], :]         #write the O atom by hand
                            temp[1] = 2
                            temp = " ".join(map(str, temp))
                            group_traj.write(temp+"\n")
                        if len(list) == 3:
                            for index in list[:-1]:
                                #print(type(index))
                                temp = self.s1[snapshot][index, :]
                                temp[1] = 3
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                            temp = self.s2[snapshot][list[-1], :]
                            temp[1] = 3
                            temp = " ".join(map(str, temp))
                            group_traj.write(temp+"\n")
                        if len(list) == 4:
                            for index in list[:-1]:
                                temp = self.s1[snapshot][index, :]
                                temp[1] = 4
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                            temp = self.s2[snapshot][list[-1], :]
                            temp[1] = 4
                            temp = " ".join(map(str, temp))
                            group_traj.write(temp+"\n")

                        if len(list) == 5:
                            for index in list[:-1]:
                                temp = self.s1[snapshot][index, :]
                                temp[1] = 5
                                temp = " ".join(map(str, temp))
                                group_traj.write(temp+"\n")
                            temp = self.s2[snapshot][list[-1], :]
                            temp[1] = 5
                            temp = " ".join(map(str, temp))
                            group_traj.write(temp+"\n")
                return

        for i in range(self.n_snapshots):
            molecules = []
            indexlist_group, _ = self.get_neighbour_KDT(mode="pbc", snapshot=i)
            for O_atom in  range(self.s2[i].shape[0]):
                temp = np.append(np.argwhere(indexlist_group == O_atom), O_atom)
                molecules.append(temp)

            write_lammpstrj(molecules, timestep, i)


        return
    
    def get_radial_diffusion(self, timestep=0.0005):
        '''
        method to calculate the radial diffusion coefficient based on 10.1103/PhysRevE.76.031203
        currently only supports non ionic water without hydrogen exchange. 
        :param dt: timestep used for integration, default=5*10e-4.
        
        '''
  
        def get_com(H_1, H_2, O):
        
            '''
            helper function to quickly calculate the CoM of each H2O molecule based on the unit circle transform
            approach https://en.wikipedia.org/wiki/Center_of_mass#Systems_with_periodic_boundary_conditions
            '''
            
            m_H = 1.00784 # values in u 
            m_O = 15.999
            
            com = np.zeros(len(H_1[0]))
                           
            box = [1, 1, 1] # scaled lammps
            
            for i in range(len(H_1[0])): #len(H_1[0] = 3) H_1 [[x, y, z]]
                theta = np.array([H_1[0][i], H_2[0][i], O[0][i]])
                theta = theta * 2 * np.pi / box[i]
                #theta = [2*h1_x * pi / 1, 2h2_x*pi/ 1, 2*O_x*pi / 1]
                xi = np.cos(theta)
                zeta = np.sin(theta)
                
                xi_avg = np.dot(xi, np.array([m_H, m_H, m_O])) / sum([m_H, m_H, m_O])
                zeta_avg = np.dot(zeta, np.array([m_H, m_H, m_O])) / sum([m_H, m_H, m_O])
                
                theta_avg = np.arctan2(-zeta_avg, -xi_avg) + np.pi
                
                com[i] = box[i] * theta_avg / (2 * np.pi)
            return com
        
        def get_p_vector(H_1, H_2, com):
            '''
            helper function to calculate the vector from the CoM towards the midpoint between both hydrogens
            the p vector is the normalized polarization vector vec(mid, CoM) / |vec(mid, CoM)|
            '''
            #pbc!!
            
            def check_pbc(x):
                

                box = [1, 1, 1]
                for index, coordinate in enumerate(x):
                    if coordinate > box[index]:
                        x[index] = coordinate - box[index]
                    if coordinate < 0:
                        x[index] = coordinate + box[index]
                return x
            
            
            box = [1, 1, 1] ##using scaled lammps coordinates

            v_shift = np.array([x/2 for x in box]) - np.array(H_1)
            
            H_1_s = H_1 + v_shift
            H_2_s = H_2 + v_shift
            com_s = com + v_shift
            
            H_1_s = check_pbc(H_1_s)
            H_2_s = check_pbc(H_2_s)
            com_s = check_pbc(com_s)
    
            mid = (H_1_s + H_2_s) / 2
            p = mid - com

            return p / np.linalg.norm(p)
        
        
        def get_delta_phi_vector(p, p_t):
            '''
            helper function to calculate the phi vector used for the rotational MSD calculation
            phi = p(t) x p(t+1) / (|p(t) x p(t+1) | * arccos(<p(t), p(t+1)>)) -> normalized + scaled
            '''
            #cos^-1 = 1/cos or arccos??
            pre_factor = np.arccos(np.dot(p, p_t))

            phi = np.cross(p, p_t) / np.linalg.norm(np.cross(p, p_t))
            
            return pre_factor * phi
        
        
        #step 1 determine molecules: for each H find the corresponding O for frame 1 
        # -> molecules should not change over time so save particle id. 
        #todo: add functionallity for non static molecules i.e water ions
            
        indexlist_group, _ = self.get_neighbour_KDT(species_1=self.s1[0], 
                                                    species_2=self.s2[0], mode="pbc", snapshot=0) 

        #lammps atom ids start counting from 1 not from 0
        atom_id_O = self.s2[0][:, 0]
        atom_id_H = self.s1[0][:, 0]
        
        molecule_list = [None] * self.s2[0].shape[0]
        
        #molecule_list is a list of tuples (H1_ind, H2_ind, O_ind) as molecule reference for later timesteps
        
        for O_atom in  range(self.s2[0].shape[0]): 

            H_1 = atom_id_H[np.argwhere(indexlist_group == O_atom)[0]][0]
            H_2 = atom_id_H[np.argwhere(indexlist_group == O_atom)[1]][0]
            O = atom_id_O[O_atom]

            molecule_list[O_atom] = (H_1, H_2, O)
    
    
        #init structures
                           
        com_list = np.zeros((self.n_snapshots, len(molecule_list), 3))
        p_list = np.zeros((self.n_snapshots, len(molecule_list), 3))
        delta_phi_list = np.zeros((self.n_snapshots, len(molecule_list), 3))
        phi_list = np.zeros((self.n_snapshots, len(molecule_list), 3))
        rot_msd_list = np.zeros(self.n_snapshots)
    
    
        #first determine the atoms of each molecule and get the center of mass + polarized vector
        # loop over each timestep - n_snapshot and do calculation for CoM and p vector for each H2O
        
        for dt in range(self.n_snapshots):
            for molecule in range(len(molecule_list)):
                # get the row indices for the current molecule
                # remember self.trajectory[dt]=(atom_id, atom_type, x, y, z) x n_atom
                H_1 = self.trajectory[dt ,self.trajectory[dt, :, 0] == molecule_list[molecule][0] , 2:]
                H_2 = self.trajectory[dt ,self.trajectory[dt, :, 0] == molecule_list[molecule][1] , 2:]
                O = self.trajectory[dt ,self.trajectory[dt, :, 0] == molecule_list[molecule][2], 2:]
        
                com_list[dt, molecule, :] = get_com(H_1, H_2, O)
                p_list [dt, molecule, :] = get_p_vector(H_1[0], H_2[0], com_list[dt, molecule, :])

        #calc the Delta_phi vector and do the time integration from 0 to current timestep to arrive 
        # at the phi(delta t) vector
        
        for dt in range(1, self.n_snapshots):
            #for delta_t in range(dt, self.n_snapshots)
            for molecule in range(len(molecule_list)):
                #note p(t) x p(t + 1) = p(t - 1) x p(t) -> shift
                delta_phi_list[dt, molecule, :] = get_delta_phi_vector(p_list[dt - 1, molecule, :],
                                                                       p_list[dt, molecule, :])
                #use https://github.com/pdebuyl-lab/tidynamics/blob/master/tidynamics/_correlation.py
                # for (r)msd calculation!
                
                # step 4 integrate delta_phi(t) from t to t+dt for t+dt, t+2dt, t+3dt.... t+n*dt > results phi(t)
                phi_list[dt, molecule, 0] = trapezoid(delta_phi_list[0:dt, molecule, 0], dx=timestep) 
                phi_list[dt, molecule, 1] = trapezoid(delta_phi_list[0:dt, molecule, 1], dx=timestep)
                phi_list[dt, molecule, 2] = trapezoid(delta_phi_list[0:dt, molecule, 2], dx=timestep)
                

        #lastly calculate the RMSD(t) = abs(phi(t) - phi(0))^2 /N_molecules  -> phi(0) always zero? does make sense tho
        #step 5 sum for all particles  rmsd(t) = sum(0 to N)|phi_i(t + dt) - phi_i(t=0)|^2 / N
        # where  rmsd(t) = rmsd(t=0), rmsd(t+dt) = rmsd(t=t+dt)..... rmsd(t+k*dt) = rmsd(t=t+k*dt) for k timesteps 
        # and i molecules
              
        for dt in range(self.n_snapshots):
            temp = 0
            for molecule in range(len(molecule_list)):        
                temp = temp + np.linalg.norm(phi_list[dt, molecule, :] - phi_list[0, molecule, :])**2 
            rot_msd_list[dt] = temp
        
        rot_msd_list = rot_msd_list / len(molecule_list)

        # step 6 plot this curve and take the slope of the linear - regime, divide by 4 -> D_rot
        # todo! -> first fix rmsd vs dt plot befor dealing with the slope
                           
        return rot_msd_list
                               
    def plot_d_rot(self, rmsd, timestep=0.0005):
    
        fig, ax = plt.subplots()

        ax.scatter(timestep*np.linspace(0,len(rmsd), len(rmsd)), rmsd, color="red", marker="x")
        ax.plot(timestep*np.linspace(0,len(rmsd), len(rmsd)), rmsd)
        ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))
        ax.xaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))
        ax.set_xlabel("$\Delta$t in ps")
        ax.grid()
        ax.set_ylabel("<$\phi^2(\Delta t)$>")
        ax.set_title("Rotational Diffusion")

        plt.show()

# %%
def generate_md_input(folder_input, folder_output, N_traj=1, format_in="lammps_data", is_scaled=1):
    '''
    Wrapperfunction to call on the trajectory class and create N_traj different input trajectories for md simmulations
    by displacing atoms to create ions from a given water-trajectory.
    :param folder_input: path to the input trajectories
    :param folder_output: path to the folder where the ion trajectories will be saved. if it does not exist it will be created
    :param N_traj: Number of trajectories to be created, default=1
    :param format_in: Format of the files in the input folder, default="lammps_data". needed to decide on the correct parser
    :param is_scaled: 1 True, 0 False if the input is in scaled lammps coordinates or not. 
    '''
    
    
    if not os.path.isdir(folder_output):
        os.mkdir(folder_output)
        
    input_files = os.listdir(folder_input)
    
    random_file_id = np.random.randint(0, len(input_files), N_traj)
    random_displace_distance = np.random.uniform(0.2, 0.4, N_traj)
    
    for i in range(N_traj):
        traj_temp = Trajectory(folder_input+input_files[random_file_id[i]], format=format_in, scaled=is_scaled)
        traj_temp.s1, traj_temp.s2 = traj_temp.split_species()
        traj_temp.indexlist, _ = traj_temp.get_neighbour_KDT(mode="pbc", snapshot=0)
        traj_temp.get_displace(snapshot=0, id=None, distance=random_displace_distance[i], eps=0.05, path=folder_output+f"{i}_")

# %%
def cut_multiple_snaps(trajectory_obj, folder_output, snapshot_list):
    '''
    Helperfunction to cut out multiply snapshot from an excisting trajectory.
    :param trajectory_obj: Trajectory class object from where the snapshots are cutout from
    :param folder_output: path of the outputfolder if such a directory does not exist it will be created
    :param snapshot_list: list of timestamps - snapshot ids - which are to be cut
    '''
    if not os.path.isdir(folder_output):
        os.mkdir(folder_output)
    
    for snap in snapshot_list:
        trajectory_obj.cut_snapshot(snap, folder_output)

# %%
#file = r'\Users\Nutzer\Documents\Python Scripts\water_traj.gro'
#file = r'C:\Users\Nutzer\Documents\Python Scripts\trjwater.lammpstrj'
#file = r'C:\Users\Nutzer\Documents\Master Thesis\data_ions_293_first\water.lammpstrj'
#file = r'/home/ibrahimk95/Documents/n2p2_sims/network_v1.0/run_1/water.lammpstrj'
#file = r'/home/ibrahimk95/Documents/n2p2_sims/working_files/needs_testing/nnp_2_0/test_run_2_early_stop/trjwater.lammpstrj'
#file = r'/home/ibrahimk95/Documents/n2p2_sims/working_files/needs_testing/trjwater.lammpstrj'
#file = r'/home/ibrahimk95/Documents/n2p2_sims/working_files/needs_testing/failed_clustering_run/trjwater.lammpstrj'
#file = r'/home/ibrahimk95/pythoncodes/ab_initio_initials_n384/water_no_ions_configs/conf_11.lampstrj'
file = r'/home/ibrahimk95/Documents/n2p2_sims/working_files/works_on_ions/ion_water_nn_v1/recombination_5/trjwater.lammpstrj'
traj = Trajectory(file, format="lammpstrj", scaled=1)
# Out:
# Processing Snapshot:1
# Processing Snapshot:2
# Processing Snapshot:3
# Processing Snapshot:4
# Processing Snapshot:5
# Processing Snapshot:6
# Processing Snapshot:7
# Processing Snapshot:8
# Processing Snapshot:9
# Processing Snapshot:10
# Processing Snapshot:11
# Processing Snapshot:12
# Processing Snapshot:13
# Processing Snapshot:14
# Processing Snapshot:15
# Processing Snapshot:16
# Processing Snapshot:17
# Processing Snapshot:18
# Processing Snapshot:19
# Processing Snapshot:20
# Processing Snapshot:21
# Processing Snapshot:22
# Processing Snapshot:23
# Processing Snapshot:24
# Processing Snapshot:25
# Processing Snapshot:26
# Processing Snapshot:27
# Processing Snapshot:28
# Processing Snapshot:29
# Processing Snapshot:30
# Processing Snapshot:31
# Processing Snapshot:32
# Processing Snapshot:33
# Processing Snapshot:34
# Processing Snapshot:35
# Processing Snapshot:36
# Processing Snapshot:37
# Processing Snapshot:38
# Processing Snapshot:39
# Processing Snapshot:40
# Processing Snapshot:41
# Processing Snapshot:42
# Processing Snapshot:43
# Processing Snapshot:44
# Processing Snapshot:45
# Processing Snapshot:46
# Processing Snapshot:47
# Processing Snapshot:48
# Processing Snapshot:49
# Processing Snapshot:50
# Processing Snapshot:51
# Processing Snapshot:52
# Processing Snapshot:53
# Processing Snapshot:54
# Processing Snapshot:55
# Processing Snapshot:56
# Processing Snapshot:57
# Processing Snapshot:58
# Processing Snapshot:59
# Processing Snapshot:60
# Processing Snapshot:61
# Processing Snapshot:62
# Processing Snapshot:63
# Processing Snapshot:64
# Processing Snapshot:65
# Processing Snapshot:66
# Processing Snapshot:67
# Processing Snapshot:68
# Processing Snapshot:69
# Processing Snapshot:70
# Processing Snapshot:71
# Processing Snapshot:72
# Processing Snapshot:73
# Processing Snapshot:74
# Processing Snapshot:75
# Processing Snapshot:76
# Processing Snapshot:77
# Processing Snapshot:78
# Processing Snapshot:79
# Processing Snapshot:80
# Processing Snapshot:81
# Processing Snapshot:82
# Processing Snapshot:83
# Processing Snapshot:84
# Processing Snapshot:85
# Processing Snapshot:86
# Processing Snapshot:87
# Processing Snapshot:88
# Processing Snapshot:89
# Processing Snapshot:90
# Processing Snapshot:91
# Processing Snapshot:92
# Processing Snapshot:93
# Processing Snapshot:94
# Processing Snapshot:95
# Processing Snapshot:96
# Processing Snapshot:97
# Processing Snapshot:98
# Processing Snapshot:99
# Processing Snapshot:100
# Processing Snapshot:101
# Processing Snapshot:102
# Processing Snapshot:103
# Processing Snapshot:104
# Processing Snapshot:105
# Processing Snapshot:106
# Processing Snapshot:107
# Processing Snapshot:108
# Processing Snapshot:109
# Processing Snapshot:110
# Processing Snapshot:111
# Processing Snapshot:112
# Processing Snapshot:113
# Processing Snapshot:114
# Processing Snapshot:115
# Processing Snapshot:116
# Processing Snapshot:117
# Processing Snapshot:118
# Processing Snapshot:119
# Processing Snapshot:120
# Processing Snapshot:121
# Processing Snapshot:122
# Processing Snapshot:123
# Processing Snapshot:124
# Processing Snapshot:125
# Processing Snapshot:126
# Processing Snapshot:127
# Processing Snapshot:128
# Processing Snapshot:129
# Processing Snapshot:130
# Processing Snapshot:131
# Processing Snapshot:132
# Processing Snapshot:133
# Processing Snapshot:134
# Processing Snapshot:135
# Processing Snapshot:136
# Processing Snapshot:137
# Processing Snapshot:138
# Processing Snapshot:139
# Processing Snapshot:140
# Processing Snapshot:141
# Processing Snapshot:142
# Processing Snapshot:143
# Processing Snapshot:144
# Processing Snapshot:145
# Processing Snapshot:146
# Processing Snapshot:147
# Processing Snapshot:148
# Processing Snapshot:149
# Processing Snapshot:150
# Processing Snapshot:151
# Processing Snapshot:152
# Processing Snapshot:153
# Processing Snapshot:154
# Processing Snapshot:155
# Processing Snapshot:156
# Processing Snapshot:157
# Processing Snapshot:158
# Processing Snapshot:159
# Processing Snapshot:160
# Processing Snapshot:161
# Processing Snapshot:162
# Processing Snapshot:163
# Processing Snapshot:164
# Processing Snapshot:165
# Processing Snapshot:166
# Processing Snapshot:167
# Processing Snapshot:168
# Processing Snapshot:169
# Processing Snapshot:170
# Processing Snapshot:171
# Processing Snapshot:172
# Processing Snapshot:173
# Processing Snapshot:174
# Processing Snapshot:175
# Processing Snapshot:176
# Processing Snapshot:177
# Processing Snapshot:178
# Processing Snapshot:179
# Processing Snapshot:180
# Processing Snapshot:181
# Processing Snapshot:182
# Processing Snapshot:183
# Processing Snapshot:184
# Processing Snapshot:185
# Processing Snapshot:186
# Processing Snapshot:187
# Processing Snapshot:188
# Processing Snapshot:189
# Processing Snapshot:190
# Processing Snapshot:191
# Processing Snapshot:192
# Processing Snapshot:193
# Processing Snapshot:194
# Processing Snapshot:195
# Processing Snapshot:196
# Processing Snapshot:197
# Processing Snapshot:198
# Processing Snapshot:199
# Processing Snapshot:200
# Processing Snapshot:201
# Processing Snapshot:202
# Processing Snapshot:203
# Processing Snapshot:204
# Processing Snapshot:205
# Processing Snapshot:206
# Processing Snapshot:207
# Processing Snapshot:208
# Processing Snapshot:209
# Processing Snapshot:210
# Processing Snapshot:211
# Processing Snapshot:212
# Processing Snapshot:213
# Processing Snapshot:214
# Processing Snapshot:215
# Processing Snapshot:216
# Processing Snapshot:217
# Processing Snapshot:218
# Processing Snapshot:219
# Processing Snapshot:220
# Processing Snapshot:221
# Processing Snapshot:222
# Processing Snapshot:223
# Processing Snapshot:224
# Processing Snapshot:225
# Processing Snapshot:226
# Processing Snapshot:227
# Processing Snapshot:228
# Processing Snapshot:229
# Processing Snapshot:230
# Processing Snapshot:231
# Processing Snapshot:232
# Processing Snapshot:233
# Processing Snapshot:234
# Processing Snapshot:235
# Processing Snapshot:236
# Processing Snapshot:237
# Processing Snapshot:238
# Processing Snapshot:239
# Processing Snapshot:240
# Processing Snapshot:241
# Processing Snapshot:242
# Processing Snapshot:243
# Processing Snapshot:244
# Processing Snapshot:245
# Processing Snapshot:246
# Processing Snapshot:247
# Processing Snapshot:248
# Processing Snapshot:249
# Processing Snapshot:250
# Processing Snapshot:251
# Processing Snapshot:252
# Processing Snapshot:253
# Processing Snapshot:254
# Processing Snapshot:255
# Processing Snapshot:256
# Processing Snapshot:257
# Processing Snapshot:258
# Processing Snapshot:259
# Processing Snapshot:260
# Processing Snapshot:261
# Processing Snapshot:262
# Processing Snapshot:263
# Processing Snapshot:264
# Processing Snapshot:265
# Processing Snapshot:266
# Processing Snapshot:267
# Processing Snapshot:268
# Processing Snapshot:269
# Processing Snapshot:270
# Processing Snapshot:271
# Processing Snapshot:272
# Processing Snapshot:273
# Processing Snapshot:274
# Processing Snapshot:275
# Processing Snapshot:276
# Processing Snapshot:277
# Processing Snapshot:278
# Processing Snapshot:279
# Processing Snapshot:280
# Processing Snapshot:281
# Processing Snapshot:282
# Processing Snapshot:283
# Processing Snapshot:284
# Processing Snapshot:285
# Processing Snapshot:286
# Processing Snapshot:287
# Processing Snapshot:288
# Processing Snapshot:289
# Processing Snapshot:290
# Processing Snapshot:291
# Processing Snapshot:292
# Processing Snapshot:293
# Processing Snapshot:294
# Processing Snapshot:295
# Processing Snapshot:296
# Processing Snapshot:297
# Processing Snapshot:298
# Processing Snapshot:299
# Processing Snapshot:300
# Processing Snapshot:301
# Processing Snapshot:302
# Processing Snapshot:303
# Processing Snapshot:304
# Processing Snapshot:305
# Processing Snapshot:306
# Processing Snapshot:307
# Processing Snapshot:308
# Processing Snapshot:309
# Processing Snapshot:310
# Processing Snapshot:311
# Processing Snapshot:312
# Processing Snapshot:313
# Processing Snapshot:314
# Processing Snapshot:315
# Processing Snapshot:316
# Processing Snapshot:317
# Processing Snapshot:318
# Processing Snapshot:319
# Processing Snapshot:320
# Processing Snapshot:321
# Processing Snapshot:322
# Processing Snapshot:323
# Processing Snapshot:324
# Processing Snapshot:325
# Processing Snapshot:326
# Processing Snapshot:327
# Processing Snapshot:328
# Processing Snapshot:329
# Processing Snapshot:330
# Processing Snapshot:331
# Processing Snapshot:332
# Processing Snapshot:333
# Processing Snapshot:334
# Processing Snapshot:335
# Processing Snapshot:336
# Processing Snapshot:337
# Processing Snapshot:338
# Processing Snapshot:339
# Processing Snapshot:340
# Processing Snapshot:341
# Processing Snapshot:342
# Processing Snapshot:343
# Processing Snapshot:344
# Processing Snapshot:345
# Processing Snapshot:346
# Processing Snapshot:347
# Processing Snapshot:348
# Processing Snapshot:349
# Processing Snapshot:350
# Processing Snapshot:351
# Processing Snapshot:352
# Processing Snapshot:353
# Processing Snapshot:354
# Processing Snapshot:355
# Processing Snapshot:356
# Processing Snapshot:357
# Processing Snapshot:358
# Processing Snapshot:359
# Processing Snapshot:360
# Processing Snapshot:361
# Processing Snapshot:362
# Processing Snapshot:363
# Processing Snapshot:364
# Processing Snapshot:365
# Processing Snapshot:366
# Processing Snapshot:367
# Processing Snapshot:368
# Processing Snapshot:369
# Processing Snapshot:370
# Processing Snapshot:371
# Processing Snapshot:372
# Processing Snapshot:373
# Processing Snapshot:374
# Processing Snapshot:375
# Processing Snapshot:376
# Processing Snapshot:377
# Processing Snapshot:378
# Processing Snapshot:379
# Processing Snapshot:380
# Processing Snapshot:381
# Processing Snapshot:382
# Processing Snapshot:383
# Processing Snapshot:384
# Processing Snapshot:385
# Processing Snapshot:386
# Processing Snapshot:387
# Processing Snapshot:388
# Processing Snapshot:389
# Processing Snapshot:390
# Processing Snapshot:391
# Processing Snapshot:392
# Processing Snapshot:393
# Processing Snapshot:394
# Processing Snapshot:395
# Processing Snapshot:396
# Processing Snapshot:397
# Processing Snapshot:398
# Processing Snapshot:399
# Processing Snapshot:400
# Processing Snapshot:401
# Processing Snapshot:402
# Processing Snapshot:403
# Processing Snapshot:404
# Processing Snapshot:405
# Processing Snapshot:406
# Processing Snapshot:407
# Processing Snapshot:408
# Processing Snapshot:409
# Processing Snapshot:410
# Processing Snapshot:411
# Processing Snapshot:412
# Processing Snapshot:413
# Processing Snapshot:414
# Processing Snapshot:415
# Processing Snapshot:416
# Processing Snapshot:417
# Processing Snapshot:418
# Processing Snapshot:419
# Processing Snapshot:420
# Processing Snapshot:421
# Processing Snapshot:422
# Processing Snapshot:423
# Processing Snapshot:424
# Processing Snapshot:425
# Processing Snapshot:426
# Processing Snapshot:427
# Processing Snapshot:428
# Processing Snapshot:429
# Processing Snapshot:430
# Processing Snapshot:431
# Processing Snapshot:432
# Processing Snapshot:433
# Processing Snapshot:434
# Processing Snapshot:435
# Processing Snapshot:436
# Processing Snapshot:437
# Processing Snapshot:438
# Processing Snapshot:439
# Processing Snapshot:440
# Processing Snapshot:441
# Processing Snapshot:442
# Processing Snapshot:443
# Processing Snapshot:444
# Processing Snapshot:445
# Processing Snapshot:446
# Processing Snapshot:447
# Processing Snapshot:448
# Processing Snapshot:449
# Processing Snapshot:450
# Processing Snapshot:451
# Processing Snapshot:452
# Processing Snapshot:453
# Processing Snapshot:454
# Processing Snapshot:455
# Processing Snapshot:456
# Processing Snapshot:457
# Processing Snapshot:458
# Processing Snapshot:459
# Processing Snapshot:460
# Processing Snapshot:461
# Processing Snapshot:462
# Processing Snapshot:463
# Processing Snapshot:464
# Processing Snapshot:465
# Processing Snapshot:466
# Processing Snapshot:467
# Processing Snapshot:468
# Processing Snapshot:469
# Processing Snapshot:470
# Processing Snapshot:471
# Processing Snapshot:472
# Processing Snapshot:473
# Processing Snapshot:474
# Processing Snapshot:475
# Processing Snapshot:476
# Processing Snapshot:477
# Processing Snapshot:478
# Processing Snapshot:479
# Processing Snapshot:480
# Processing Snapshot:481
# Processing Snapshot:482
# Processing Snapshot:483
# Processing Snapshot:484
# Processing Snapshot:485
# Processing Snapshot:486
# Processing Snapshot:487
# Processing Snapshot:488
# Processing Snapshot:489
# Processing Snapshot:490
# Processing Snapshot:491
# Processing Snapshot:492
# Processing Snapshot:493
# Processing Snapshot:494
# Processing Snapshot:495
# Processing Snapshot:496
# Processing Snapshot:497
# Processing Snapshot:498
# Processing Snapshot:499
# Processing Snapshot:500
# Processing Snapshot:501
# Processing Snapshot:502
# Processing Snapshot:503
# Processing Snapshot:504
# Processing Snapshot:505
# Processing Snapshot:506
# Processing Snapshot:507
# Processing Snapshot:508
# Processing Snapshot:509
# Processing Snapshot:510
# Processing Snapshot:511
# Processing Snapshot:512
# Processing Snapshot:513
# Processing Snapshot:514
# Processing Snapshot:515
# Processing Snapshot:516
# Processing Snapshot:517
# Processing Snapshot:518
# Processing Snapshot:519
# Processing Snapshot:520
# Processing Snapshot:521
# Processing Snapshot:522
# Processing Snapshot:523
# Processing Snapshot:524
# Processing Snapshot:525
# Processing Snapshot:526
# Processing Snapshot:527
# Processing Snapshot:528
# Processing Snapshot:529
# Processing Snapshot:530
# Processing Snapshot:531
# Processing Snapshot:532
# Processing Snapshot:533
# Processing Snapshot:534
# Processing Snapshot:535
# Processing Snapshot:536
# Processing Snapshot:537
# Processing Snapshot:538
# Processing Snapshot:539
# Processing Snapshot:540
# Processing Snapshot:541
# Processing Snapshot:542
# Processing Snapshot:543
# Processing Snapshot:544
# Processing Snapshot:545
# Processing Snapshot:546
# Processing Snapshot:547
# Processing Snapshot:548
# Processing Snapshot:549
# Processing Snapshot:550
# Processing Snapshot:551
# Processing Snapshot:552
# Processing Snapshot:553
# Processing Snapshot:554
# Processing Snapshot:555
# Processing Snapshot:556
# Processing Snapshot:557
# Processing Snapshot:558
# Processing Snapshot:559
# Processing Snapshot:560
# Processing Snapshot:561
# Processing Snapshot:562
# Processing Snapshot:563
# Processing Snapshot:564
# Processing Snapshot:565
# Processing Snapshot:566
# Processing Snapshot:567
# Processing Snapshot:568
# Processing Snapshot:569
# Processing Snapshot:570
# Processing Snapshot:571
# Processing Snapshot:572
# Processing Snapshot:573
# Processing Snapshot:574
# Processing Snapshot:575
# Processing Snapshot:576
# Processing Snapshot:577
# Processing Snapshot:578
# Processing Snapshot:579
# Processing Snapshot:580
# Processing Snapshot:581
# Processing Snapshot:582
# Processing Snapshot:583
# Processing Snapshot:584
# Processing Snapshot:585
# Processing Snapshot:586
# Processing Snapshot:587
# Processing Snapshot:588
# Processing Snapshot:589
# Processing Snapshot:590
# Processing Snapshot:591
# Processing Snapshot:592
# Processing Snapshot:593
# Processing Snapshot:594
# Processing Snapshot:595
# Processing Snapshot:596
# Processing Snapshot:597
# Processing Snapshot:598
# Processing Snapshot:599
# Processing Snapshot:600
# Processing Snapshot:601
# Processing Snapshot:602
# Processing Snapshot:603
# Processing Snapshot:604
# Processing Snapshot:605
# Processing Snapshot:606
# Processing Snapshot:607
# Processing Snapshot:608
# Processing Snapshot:609
# Processing Snapshot:610
# Processing Snapshot:611
# Processing Snapshot:612
# Processing Snapshot:613
# Processing Snapshot:614
# Processing Snapshot:615
# Processing Snapshot:616
# Processing Snapshot:617
# Processing Snapshot:618
# Processing Snapshot:619
# Processing Snapshot:620
# Processing Snapshot:621
# Processing Snapshot:622
# Processing Snapshot:623
# Processing Snapshot:624
# Processing Snapshot:625
# Processing Snapshot:626
# Processing Snapshot:627
# Processing Snapshot:628
# Processing Snapshot:629
# Processing Snapshot:630
# Processing Snapshot:631
# Processing Snapshot:632
# Processing Snapshot:633
# Processing Snapshot:634
# Processing Snapshot:635
# Processing Snapshot:636
# Processing Snapshot:637
# Processing Snapshot:638
# Processing Snapshot:639
# Processing Snapshot:640
# Processing Snapshot:641
# Processing Snapshot:642
# Processing Snapshot:643
# Processing Snapshot:644
# Processing Snapshot:645
# Processing Snapshot:646
# Processing Snapshot:647
# Processing Snapshot:648
# Processing Snapshot:649
# Processing Snapshot:650
# Processing Snapshot:651
# Processing Snapshot:652
# Processing Snapshot:653
# Processing Snapshot:654
# Processing Snapshot:655
# Processing Snapshot:656
# Processing Snapshot:657
# Processing Snapshot:658
# Processing Snapshot:659
# Processing Snapshot:660
# Processing Snapshot:661
# Processing Snapshot:662
# Processing Snapshot:663
# Processing Snapshot:664
# Processing Snapshot:665
# Processing Snapshot:666
# Processing Snapshot:667
# Processing Snapshot:668
# Processing Snapshot:669
# Processing Snapshot:670
# Processing Snapshot:671
# Processing Snapshot:672
# Processing Snapshot:673
# Processing Snapshot:674
# Processing Snapshot:675
# Processing Snapshot:676
# Processing Snapshot:677
# Processing Snapshot:678
# Processing Snapshot:679
# Processing Snapshot:680
# Processing Snapshot:681
# Processing Snapshot:682
# Processing Snapshot:683
# Processing Snapshot:684
# Processing Snapshot:685
# Processing Snapshot:686
# Processing Snapshot:687
# Processing Snapshot:688
# Processing Snapshot:689
# Processing Snapshot:690
# Processing Snapshot:691
# Processing Snapshot:692
# Processing Snapshot:693
# Processing Snapshot:694
# Processing Snapshot:695
# Processing Snapshot:696
# Processing Snapshot:697
# Processing Snapshot:698
# Processing Snapshot:699
# Processing Snapshot:700
# Processing Snapshot:701
# Processing Snapshot:702
# Processing Snapshot:703
# Processing Snapshot:704
# Processing Snapshot:705
# Processing Snapshot:706
# Processing Snapshot:707
# Processing Snapshot:708
# Processing Snapshot:709
# Processing Snapshot:710
# Processing Snapshot:711
# Processing Snapshot:712
# Processing Snapshot:713
# Processing Snapshot:714
# Processing Snapshot:715
# Processing Snapshot:716
# Processing Snapshot:717
# Processing Snapshot:718
# Processing Snapshot:719
# Processing Snapshot:720
# Processing Snapshot:721
# Processing Snapshot:722
# Processing Snapshot:723
# Processing Snapshot:724
# Processing Snapshot:725
# Processing Snapshot:726
# Processing Snapshot:727
# Processing Snapshot:728
# Processing Snapshot:729
# Processing Snapshot:730
# Processing Snapshot:731
# Processing Snapshot:732
# Processing Snapshot:733
# Processing Snapshot:734
# Processing Snapshot:735
# Processing Snapshot:736
# Processing Snapshot:737
# Processing Snapshot:738
# Processing Snapshot:739
# Processing Snapshot:740
# Processing Snapshot:741
# Processing Snapshot:742
# Processing Snapshot:743
# Processing Snapshot:744
# Processing Snapshot:745
# Processing Snapshot:746
# Processing Snapshot:747
# Processing Snapshot:748
# Processing Snapshot:749
# Processing Snapshot:750
# Processing Snapshot:751
# Processing Snapshot:752
# Processing Snapshot:753
# Processing Snapshot:754
# Processing Snapshot:755
# Processing Snapshot:756
# Processing Snapshot:757
# Processing Snapshot:758
# Processing Snapshot:759
# Processing Snapshot:760
# Processing Snapshot:761
# Processing Snapshot:762
# Processing Snapshot:763
# Processing Snapshot:764
# Processing Snapshot:765
# Processing Snapshot:766
# Processing Snapshot:767
# Processing Snapshot:768
# Processing Snapshot:769
# Processing Snapshot:770
# Processing Snapshot:771
# Processing Snapshot:772
# Processing Snapshot:773
# Processing Snapshot:774
# Processing Snapshot:775
# Processing Snapshot:776
# Processing Snapshot:777
# Processing Snapshot:778
# Processing Snapshot:779
# Processing Snapshot:780
# Processing Snapshot:781
# Processing Snapshot:782
# Processing Snapshot:783
# Processing Snapshot:784
# Processing Snapshot:785
# Processing Snapshot:786
# Processing Snapshot:787
# Processing Snapshot:788
# Processing Snapshot:789
# Processing Snapshot:790
# Processing Snapshot:791
# Processing Snapshot:792
# Processing Snapshot:793
# Processing Snapshot:794
# Processing Snapshot:795
# Processing Snapshot:796
# Processing Snapshot:797
# Processing Snapshot:798
# Processing Snapshot:799
# Processing Snapshot:800
# Processing Snapshot:801
# Processing Snapshot:802
# Processing Snapshot:803
# Processing Snapshot:804
# Processing Snapshot:805
# Processing Snapshot:806
# Processing Snapshot:807
# Processing Snapshot:808
# Processing Snapshot:809
# Processing Snapshot:810
# Processing Snapshot:811
# Processing Snapshot:812
# Processing Snapshot:813
# Processing Snapshot:814
# Processing Snapshot:815
# Processing Snapshot:816
# Processing Snapshot:817
# Processing Snapshot:818
# Processing Snapshot:819
# Processing Snapshot:820
# Processing Snapshot:821
# Processing Snapshot:822
# Processing Snapshot:823
# Processing Snapshot:824
# Processing Snapshot:825
# Processing Snapshot:826
# Processing Snapshot:827
# Processing Snapshot:828
# Processing Snapshot:829
# Processing Snapshot:830
# Processing Snapshot:831
# Processing Snapshot:832
# Processing Snapshot:833
# Processing Snapshot:834
# Processing Snapshot:835
# Processing Snapshot:836
# Processing Snapshot:837
# Processing Snapshot:838
# Processing Snapshot:839
# Processing Snapshot:840
# Processing Snapshot:841
# Processing Snapshot:842
# Processing Snapshot:843
# Processing Snapshot:844
# Processing Snapshot:845
# Processing Snapshot:846
# Processing Snapshot:847
# Processing Snapshot:848
# Processing Snapshot:849
# Processing Snapshot:850
# Processing Snapshot:851
# Processing Snapshot:852
# Processing Snapshot:853
# Processing Snapshot:854
# Processing Snapshot:855
# Processing Snapshot:856
# Processing Snapshot:857
# Processing Snapshot:858
# Processing Snapshot:859
# Processing Snapshot:860
# Processing Snapshot:861
# Processing Snapshot:862
# Processing Snapshot:863
# Processing Snapshot:864
# Processing Snapshot:865
# Processing Snapshot:866
# Processing Snapshot:867
# Processing Snapshot:868
# Processing Snapshot:869
# Processing Snapshot:870
# Processing Snapshot:871
# Processing Snapshot:872
# Processing Snapshot:873
# Processing Snapshot:874
# Processing Snapshot:875
# Processing Snapshot:876
# Processing Snapshot:877
# Processing Snapshot:878
# Processing Snapshot:879
# Processing Snapshot:880
# Processing Snapshot:881
# Processing Snapshot:882
# Processing Snapshot:883
# Processing Snapshot:884
# Processing Snapshot:885
# Processing Snapshot:886
# Processing Snapshot:887
# Processing Snapshot:888
# Processing Snapshot:889
# Processing Snapshot:890
# Processing Snapshot:891
# Processing Snapshot:892
# Processing Snapshot:893
# Processing Snapshot:894
# Processing Snapshot:895
# Processing Snapshot:896
# Processing Snapshot:897
# Processing Snapshot:898
# Processing Snapshot:899
# Processing Snapshot:900
# Processing Snapshot:901
# Processing Snapshot:902
# Processing Snapshot:903
# Processing Snapshot:904
# Processing Snapshot:905
# Processing Snapshot:906
# Processing Snapshot:907
# Processing Snapshot:908
# Processing Snapshot:909
# Processing Snapshot:910
# Processing Snapshot:911
# Processing Snapshot:912
# Processing Snapshot:913
# Processing Snapshot:914
# Processing Snapshot:915
# Processing Snapshot:916
# Processing Snapshot:917
# Processing Snapshot:918
# Processing Snapshot:919
# Processing Snapshot:920
# Processing Snapshot:921
# Processing Snapshot:922
# Processing Snapshot:923
# Processing Snapshot:924
# Processing Snapshot:925
# Processing Snapshot:926
# Processing Snapshot:927
# Processing Snapshot:928
# Processing Snapshot:929
# Processing Snapshot:930
# Processing Snapshot:931
# Processing Snapshot:932
# Processing Snapshot:933
# Processing Snapshot:934
# Processing Snapshot:935
# Processing Snapshot:936
# Processing Snapshot:937
# Processing Snapshot:938
# Processing Snapshot:939
# Processing Snapshot:940
# Processing Snapshot:941
# Processing Snapshot:942
# Processing Snapshot:943
# Processing Snapshot:944
# Processing Snapshot:945
# Processing Snapshot:946
# Processing Snapshot:947
# Processing Snapshot:948
# Processing Snapshot:949
# Processing Snapshot:950
# Processing Snapshot:951
# Processing Snapshot:952
# Processing Snapshot:953
# Processing Snapshot:954
# Processing Snapshot:955
# Processing Snapshot:956
# Processing Snapshot:957
# Processing Snapshot:958
# Processing Snapshot:959
# Processing Snapshot:960
# Processing Snapshot:961
# Processing Snapshot:962
# Processing Snapshot:963
# Processing Snapshot:964
# Processing Snapshot:965
# Processing Snapshot:966
# Processing Snapshot:967
# Processing Snapshot:968
# Processing Snapshot:969
# Processing Snapshot:970
# Processing Snapshot:971
# Processing Snapshot:972
# Processing Snapshot:973
# Processing Snapshot:974
# Processing Snapshot:975
# Processing Snapshot:976
# Processing Snapshot:977
# Processing Snapshot:978
# Processing Snapshot:979
# Processing Snapshot:980
# Processing Snapshot:981
# Processing Snapshot:982
# Processing Snapshot:983
# Processing Snapshot:984
# Processing Snapshot:985
# Processing Snapshot:986
# Processing Snapshot:987
# Processing Snapshot:988
# Processing Snapshot:989
# Processing Snapshot:990
# Processing Snapshot:991
# Processing Snapshot:992
# Processing Snapshot:993
# Processing Snapshot:994
# Processing Snapshot:995
# Processing Snapshot:996
# Processing Snapshot:997
# Processing Snapshot:998
# Processing Snapshot:999
# Processing Snapshot:1000
# Processing Snapshot:1001
# Processing Snapshot:1002
# Processing Snapshot:1003
# Processing Snapshot:1004
# Processing Snapshot:1005
# Processing Snapshot:1006
# Processing Snapshot:1007
# Processing Snapshot:1008
# Processing Snapshot:1009
# Processing Snapshot:1010
# Processing Snapshot:1011
# Processing Snapshot:1012
# Processing Snapshot:1013
# Processing Snapshot:1014
# Processing Snapshot:1015
# Processing Snapshot:1016
# Processing Snapshot:1017
# Processing Snapshot:1018
# Processing Snapshot:1019
# Processing Snapshot:1020
# Processing Snapshot:1021
# Processing Snapshot:1022
# Processing Snapshot:1023
# Processing Snapshot:1024
# Processing Snapshot:1025
# Processing Snapshot:1026
# Processing Snapshot:1027
# Processing Snapshot:1028
# Processing Snapshot:1029
# Processing Snapshot:1030
# Processing Snapshot:1031
# Processing Snapshot:1032
# Processing Snapshot:1033
# Processing Snapshot:1034
# Processing Snapshot:1035
# Processing Snapshot:1036
# Processing Snapshot:1037
# Processing Snapshot:1038
# Processing Snapshot:1039
# Processing Snapshot:1040
# Processing Snapshot:1041
# Processing Snapshot:1042
# Processing Snapshot:1043
# Processing Snapshot:1044
# Processing Snapshot:1045
# Processing Snapshot:1046
# Processing Snapshot:1047
# Processing Snapshot:1048
# Processing Snapshot:1049
# Processing Snapshot:1050
# Processing Snapshot:1051
# Processing Snapshot:1052
# Processing Snapshot:1053
# Processing Snapshot:1054
# Processing Snapshot:1055
# Processing Snapshot:1056
# Processing Snapshot:1057
# Processing Snapshot:1058
# Processing Snapshot:1059
# Processing Snapshot:1060
# Processing Snapshot:1061
# Processing Snapshot:1062
# Processing Snapshot:1063
# Processing Snapshot:1064
# Processing Snapshot:1065
# Processing Snapshot:1066
# Processing Snapshot:1067
# Processing Snapshot:1068
# Processing Snapshot:1069
# Processing Snapshot:1070
# Processing Snapshot:1071
# Processing Snapshot:1072
# Processing Snapshot:1073
# Processing Snapshot:1074
# Processing Snapshot:1075
# Processing Snapshot:1076
# Processing Snapshot:1077
# Processing Snapshot:1078
# Processing Snapshot:1079
# Processing Snapshot:1080
# Processing Snapshot:1081
# Processing Snapshot:1082
# Processing Snapshot:1083
# Processing Snapshot:1084
# Processing Snapshot:1085
# Processing Snapshot:1086
# Processing Snapshot:1087
# Processing Snapshot:1088
# Processing Snapshot:1089
# Processing Snapshot:1090
# Processing Snapshot:1091
# Processing Snapshot:1092
# Processing Snapshot:1093
# Processing Snapshot:1094
# Processing Snapshot:1095
# Processing Snapshot:1096
# Processing Snapshot:1097
# Processing Snapshot:1098
# Processing Snapshot:1099
# Processing Snapshot:1100
# Processing Snapshot:1101
# Processing Snapshot:1102
# Processing Snapshot:1103
# Processing Snapshot:1104
# Processing Snapshot:1105
# Processing Snapshot:1106
# Processing Snapshot:1107
# Processing Snapshot:1108
# Processing Snapshot:1109
# Processing Snapshot:1110
# Processing Snapshot:1111
# Processing Snapshot:1112
# Processing Snapshot:1113
# Processing Snapshot:1114
# Processing Snapshot:1115
# Processing Snapshot:1116
# Processing Snapshot:1117
# Processing Snapshot:1118
# Processing Snapshot:1119
# Processing Snapshot:1120
# Processing Snapshot:1121
# Processing Snapshot:1122
# Processing Snapshot:1123
# Processing Snapshot:1124
# Processing Snapshot:1125
# Processing Snapshot:1126
# Processing Snapshot:1127
# Processing Snapshot:1128
# Processing Snapshot:1129
# Processing Snapshot:1130
# Processing Snapshot:1131
# Processing Snapshot:1132
# Processing Snapshot:1133
# Processing Snapshot:1134
# Processing Snapshot:1135
# Processing Snapshot:1136
# Processing Snapshot:1137
# Processing Snapshot:1138
# Processing Snapshot:1139
# Processing Snapshot:1140
# Processing Snapshot:1141
# Processing Snapshot:1142
# Processing Snapshot:1143
# Processing Snapshot:1144
# Processing Snapshot:1145
# Processing Snapshot:1146
# Processing Snapshot:1147
# Processing Snapshot:1148
# Processing Snapshot:1149
# Processing Snapshot:1150
# Processing Snapshot:1151
# Processing Snapshot:1152
# Processing Snapshot:1153
# Processing Snapshot:1154
# Processing Snapshot:1155
# Processing Snapshot:1156
# Processing Snapshot:1157
# Processing Snapshot:1158
# Processing Snapshot:1159
# Processing Snapshot:1160
# Processing Snapshot:1161
# Processing Snapshot:1162
# Processing Snapshot:1163
# Processing Snapshot:1164
# Processing Snapshot:1165
# Processing Snapshot:1166
# Processing Snapshot:1167
# Processing Snapshot:1168
# Processing Snapshot:1169
# Processing Snapshot:1170
# Processing Snapshot:1171
# Processing Snapshot:1172
# Processing Snapshot:1173
# Processing Snapshot:1174
# Processing Snapshot:1175
# Processing Snapshot:1176
# Processing Snapshot:1177
# Processing Snapshot:1178
# Processing Snapshot:1179
# Processing Snapshot:1180
# Processing Snapshot:1181
# Processing Snapshot:1182
# Processing Snapshot:1183
# Processing Snapshot:1184
# Processing Snapshot:1185
# Processing Snapshot:1186
# Processing Snapshot:1187
# Processing Snapshot:1188
# Processing Snapshot:1189
# Processing Snapshot:1190
# Processing Snapshot:1191
# Processing Snapshot:1192
# Processing Snapshot:1193
# Processing Snapshot:1194
# Processing Snapshot:1195
# Processing Snapshot:1196
# Processing Snapshot:1197
# Processing Snapshot:1198
# Processing Snapshot:1199
# Processing Snapshot:1200
# Processing Snapshot:1201
# Processing Snapshot:1202
# Processing Snapshot:1203
# Processing Snapshot:1204
# Processing Snapshot:1205
# Processing Snapshot:1206
# Processing Snapshot:1207
# Processing Snapshot:1208
# Processing Snapshot:1209
# Processing Snapshot:1210
# Processing Snapshot:1211
# Processing Snapshot:1212
# Processing Snapshot:1213
# Processing Snapshot:1214
# Processing Snapshot:1215
# Processing Snapshot:1216
# Processing Snapshot:1217
# Processing Snapshot:1218
# Processing Snapshot:1219
# Processing Snapshot:1220
# Processing Snapshot:1221
# Processing Snapshot:1222
# Processing Snapshot:1223
# Processing Snapshot:1224
# Processing Snapshot:1225
# Processing Snapshot:1226
# Processing Snapshot:1227
# Processing Snapshot:1228
# Processing Snapshot:1229
# Processing Snapshot:1230
# Processing Snapshot:1231
# Processing Snapshot:1232
# Processing Snapshot:1233
# Processing Snapshot:1234
# Processing Snapshot:1235
# Processing Snapshot:1236
# Processing Snapshot:1237
# Processing Snapshot:1238
# Processing Snapshot:1239
# Processing Snapshot:1240
# Processing Snapshot:1241
# Processing Snapshot:1242
# Processing Snapshot:1243
# Processing Snapshot:1244
# Processing Snapshot:1245
# Processing Snapshot:1246
# Processing Snapshot:1247
# Processing Snapshot:1248
# Processing Snapshot:1249
# Processing Snapshot:1250
# Processing Snapshot:1251
# Processing Snapshot:1252
# Processing Snapshot:1253
# Processing Snapshot:1254
# Processing Snapshot:1255
# Processing Snapshot:1256
# Processing Snapshot:1257
# Processing Snapshot:1258
# Processing Snapshot:1259
# Processing Snapshot:1260
# Processing Snapshot:1261
# Processing Snapshot:1262
# Processing Snapshot:1263
# Processing Snapshot:1264
# Processing Snapshot:1265
# Processing Snapshot:1266
# Processing Snapshot:1267
# Processing Snapshot:1268
# Processing Snapshot:1269
# Processing Snapshot:1270
# Processing Snapshot:1271
# Processing Snapshot:1272
# Processing Snapshot:1273
# Processing Snapshot:1274
# Processing Snapshot:1275
# Processing Snapshot:1276
# Processing Snapshot:1277
# Processing Snapshot:1278
# Processing Snapshot:1279
# Processing Snapshot:1280
# Processing Snapshot:1281
# Processing Snapshot:1282
# Processing Snapshot:1283
# Processing Snapshot:1284
# Processing Snapshot:1285
# Processing Snapshot:1286
# Processing Snapshot:1287
# Processing Snapshot:1288
# Processing Snapshot:1289
# Processing Snapshot:1290
# Processing Snapshot:1291
# Processing Snapshot:1292
# Processing Snapshot:1293
# Processing Snapshot:1294
# Processing Snapshot:1295
# Processing Snapshot:1296
# Processing Snapshot:1297
# Processing Snapshot:1298
# Processing Snapshot:1299
# Processing Snapshot:1300
# Processing Snapshot:1301
# Processing Snapshot:1302
# Processing Snapshot:1303
# Processing Snapshot:1304
# Processing Snapshot:1305
# Processing Snapshot:1306
# Processing Snapshot:1307
# Processing Snapshot:1308
# Processing Snapshot:1309
# Processing Snapshot:1310
# Processing Snapshot:1311
# Processing Snapshot:1312
# Processing Snapshot:1313
# Processing Snapshot:1314
# Processing Snapshot:1315
# Processing Snapshot:1316
# Processing Snapshot:1317
# Processing Snapshot:1318
# Processing Snapshot:1319
# Processing Snapshot:1320
# Processing Snapshot:1321
# Processing Snapshot:1322
# Processing Snapshot:1323
# Processing Snapshot:1324
# Processing Snapshot:1325
# Processing Snapshot:1326
# Processing Snapshot:1327
# Processing Snapshot:1328
# Processing Snapshot:1329
# Processing Snapshot:1330
# Processing Snapshot:1331
# Processing Snapshot:1332
# Processing Snapshot:1333
# Processing Snapshot:1334
# Processing Snapshot:1335
# Processing Snapshot:1336
# Processing Snapshot:1337
# Processing Snapshot:1338
# Processing Snapshot:1339
# Processing Snapshot:1340
# Processing Snapshot:1341
# Processing Snapshot:1342
# Processing Snapshot:1343
# Processing Snapshot:1344
# Processing Snapshot:1345
# Processing Snapshot:1346
# Processing Snapshot:1347
# Processing Snapshot:1348
# Processing Snapshot:1349
# Processing Snapshot:1350
# Processing Snapshot:1351
# Processing Snapshot:1352
# Processing Snapshot:1353
# Processing Snapshot:1354
# Processing Snapshot:1355
# Processing Snapshot:1356
# Processing Snapshot:1357
# Processing Snapshot:1358
# Processing Snapshot:1359
# Processing Snapshot:1360
# Processing Snapshot:1361
# Processing Snapshot:1362
# Processing Snapshot:1363
# Processing Snapshot:1364
# Processing Snapshot:1365
# Processing Snapshot:1366
# Processing Snapshot:1367
# Processing Snapshot:1368
# Processing Snapshot:1369
# Processing Snapshot:1370
# Processing Snapshot:1371
# Processing Snapshot:1372
# Processing Snapshot:1373
# Processing Snapshot:1374
# Processing Snapshot:1375
# Processing Snapshot:1376
# Processing Snapshot:1377
# Processing Snapshot:1378
# Processing Snapshot:1379
# Processing Snapshot:1380
# Processing Snapshot:1381
# Processing Snapshot:1382
# Processing Snapshot:1383
# Processing Snapshot:1384
# Processing Snapshot:1385
# Processing Snapshot:1386
# Processing Snapshot:1387
# Processing Snapshot:1388
# Processing Snapshot:1389
# Processing Snapshot:1390
# Processing Snapshot:1391
# Processing Snapshot:1392
# Processing Snapshot:1393
# Processing Snapshot:1394
# Processing Snapshot:1395
# Processing Snapshot:1396
# Processing Snapshot:1397
# Processing Snapshot:1398
# Processing Snapshot:1399
# Processing Snapshot:1400
# Processing Snapshot:1401
# Processing Snapshot:1402
# Processing Snapshot:1403
# Processing Snapshot:1404
# Processing Snapshot:1405
# Processing Snapshot:1406
# Processing Snapshot:1407
# Processing Snapshot:1408
# Processing Snapshot:1409
# Processing Snapshot:1410
# Processing Snapshot:1411
# Processing Snapshot:1412
# Processing Snapshot:1413
# Processing Snapshot:1414
# Processing Snapshot:1415
# Processing Snapshot:1416
# Processing Snapshot:1417
# Processing Snapshot:1418
# Processing Snapshot:1419
# Processing Snapshot:1420
# Processing Snapshot:1421
# Processing Snapshot:1422
# Processing Snapshot:1423
# Processing Snapshot:1424
# Processing Snapshot:1425
# Processing Snapshot:1426
# Processing Snapshot:1427
# Processing Snapshot:1428
# Processing Snapshot:1429
# Processing Snapshot:1430
# Processing Snapshot:1431
# Processing Snapshot:1432
# Processing Snapshot:1433
# Processing Snapshot:1434
# Processing Snapshot:1435
# Processing Snapshot:1436
# Processing Snapshot:1437
# Processing Snapshot:1438
# Processing Snapshot:1439
# Processing Snapshot:1440
# Processing Snapshot:1441
# Processing Snapshot:1442
# Processing Snapshot:1443
# Processing Snapshot:1444
# Processing Snapshot:1445
# Processing Snapshot:1446
# Processing Snapshot:1447
# Processing Snapshot:1448
# Processing Snapshot:1449
# Processing Snapshot:1450
# Processing Snapshot:1451
# Processing Snapshot:1452
# Processing Snapshot:1453
# Processing Snapshot:1454
# Processing Snapshot:1455
# Processing Snapshot:1456
# Processing Snapshot:1457
# Processing Snapshot:1458
# Processing Snapshot:1459
# Processing Snapshot:1460
# Processing Snapshot:1461
# Processing Snapshot:1462
# Processing Snapshot:1463
# Processing Snapshot:1464
# Processing Snapshot:1465
# Processing Snapshot:1466
# Processing Snapshot:1467
# Processing Snapshot:1468
# Processing Snapshot:1469
# Processing Snapshot:1470
# Processing Snapshot:1471
# Processing Snapshot:1472
# Processing Snapshot:1473
# Processing Snapshot:1474
# Processing Snapshot:1475
# Processing Snapshot:1476
# Processing Snapshot:1477
# Processing Snapshot:1478
# Processing Snapshot:1479
# Processing Snapshot:1480
# Processing Snapshot:1481
# Processing Snapshot:1482
# Processing Snapshot:1483
# Processing Snapshot:1484
# Processing Snapshot:1485
# Processing Snapshot:1486
# Processing Snapshot:1487
# Processing Snapshot:1488
# Processing Snapshot:1489
# Processing Snapshot:1490
# Processing Snapshot:1491
# Processing Snapshot:1492
# Processing Snapshot:1493
# Processing Snapshot:1494
# Processing Snapshot:1495
# Processing Snapshot:1496
# Processing Snapshot:1497
# Processing Snapshot:1498
# Processing Snapshot:1499
# Processing Snapshot:1500
# Processing Snapshot:1501
# Processing Snapshot:1502
# Processing Snapshot:1503
# Processing Snapshot:1504
# Processing Snapshot:1505
# Processing Snapshot:1506
# Processing Snapshot:1507
# Processing Snapshot:1508
# Processing Snapshot:1509
# Processing Snapshot:1510
# Processing Snapshot:1511
# Processing Snapshot:1512
# Processing Snapshot:1513
# Processing Snapshot:1514
# Processing Snapshot:1515
# Processing Snapshot:1516
# Processing Snapshot:1517
# Processing Snapshot:1518
# Processing Snapshot:1519
# Processing Snapshot:1520
# Processing Snapshot:1521
# Processing Snapshot:1522
# Processing Snapshot:1523
# Processing Snapshot:1524
# Processing Snapshot:1525
# Processing Snapshot:1526
# Processing Snapshot:1527
# Processing Snapshot:1528
# Processing Snapshot:1529
# Processing Snapshot:1530
# Processing Snapshot:1531
# Processing Snapshot:1532
# Processing Snapshot:1533
# Processing Snapshot:1534
# Processing Snapshot:1535
# Processing Snapshot:1536
# Processing Snapshot:1537
# Processing Snapshot:1538
# Processing Snapshot:1539
# Processing Snapshot:1540
# Processing Snapshot:1541
# Processing Snapshot:1542
# Processing Snapshot:1543
# Processing Snapshot:1544
# Processing Snapshot:1545
# Processing Snapshot:1546
# Processing Snapshot:1547
# Processing Snapshot:1548
# Processing Snapshot:1549
# Processing Snapshot:1550
# Processing Snapshot:1551
# Processing Snapshot:1552
# Processing Snapshot:1553
# Processing Snapshot:1554
# Processing Snapshot:1555
# Processing Snapshot:1556
# Processing Snapshot:1557
# Processing Snapshot:1558
# Processing Snapshot:1559
# Processing Snapshot:1560
# Processing Snapshot:1561
# Processing Snapshot:1562
# Processing Snapshot:1563
# Processing Snapshot:1564
# Processing Snapshot:1565
# Processing Snapshot:1566
# Processing Snapshot:1567
# Processing Snapshot:1568
# Processing Snapshot:1569
# Processing Snapshot:1570
# Processing Snapshot:1571
# Processing Snapshot:1572
# Processing Snapshot:1573
# Processing Snapshot:1574
# Processing Snapshot:1575
# Processing Snapshot:1576
# Processing Snapshot:1577
# Processing Snapshot:1578
# Processing Snapshot:1579
# Processing Snapshot:1580
# Processing Snapshot:1581
# Processing Snapshot:1582
# Processing Snapshot:1583
# Processing Snapshot:1584
# Processing Snapshot:1585
# Processing Snapshot:1586
# Processing Snapshot:1587
# Processing Snapshot:1588
# Processing Snapshot:1589
# Processing Snapshot:1590
# Processing Snapshot:1591
# Processing Snapshot:1592
# Processing Snapshot:1593
# Processing Snapshot:1594
# Processing Snapshot:1595
# Processing Snapshot:1596
# Processing Snapshot:1597
# Processing Snapshot:1598
# Processing Snapshot:1599
# Processing Snapshot:1600
# Processing Snapshot:1601
# Processing Snapshot:1602
# Processing Snapshot:1603
# Processing Snapshot:1604
# Processing Snapshot:1605
# Processing Snapshot:1606
# Processing Snapshot:1607
# Processing Snapshot:1608
# Processing Snapshot:1609
# Processing Snapshot:1610
# Processing Snapshot:1611
# Processing Snapshot:1612
# Processing Snapshot:1613
# Processing Snapshot:1614
# Processing Snapshot:1615
# Processing Snapshot:1616
# Processing Snapshot:1617
# Processing Snapshot:1618
# Processing Snapshot:1619
# Processing Snapshot:1620
# Processing Snapshot:1621
# Processing Snapshot:1622
# Processing Snapshot:1623
# Processing Snapshot:1624
# Processing Snapshot:1625
# Processing Snapshot:1626
# Processing Snapshot:1627
# Processing Snapshot:1628
# Processing Snapshot:1629
# Processing Snapshot:1630
# Processing Snapshot:1631
# Processing Snapshot:1632
# Processing Snapshot:1633
# Processing Snapshot:1634
# Processing Snapshot:1635
# Processing Snapshot:1636
# Processing Snapshot:1637
# Processing Snapshot:1638
# Processing Snapshot:1639
# Processing Snapshot:1640
# Processing Snapshot:1641
# Processing Snapshot:1642
# Processing Snapshot:1643
# Processing Snapshot:1644
# Processing Snapshot:1645
# Processing Snapshot:1646
# Processing Snapshot:1647
# Processing Snapshot:1648
# Processing Snapshot:1649
# Processing Snapshot:1650
# Processing Snapshot:1651
# Processing Snapshot:1652
# Processing Snapshot:1653
# Processing Snapshot:1654
# Processing Snapshot:1655
# Processing Snapshot:1656
# Processing Snapshot:1657
# Processing Snapshot:1658
# Processing Snapshot:1659
# Processing Snapshot:1660
# Processing Snapshot:1661
# Processing Snapshot:1662
# Processing Snapshot:1663
# Processing Snapshot:1664
# Processing Snapshot:1665
# Processing Snapshot:1666
# Processing Snapshot:1667
# Processing Snapshot:1668
# Processing Snapshot:1669
# Processing Snapshot:1670
# Processing Snapshot:1671
# Processing Snapshot:1672
# Processing Snapshot:1673
# Processing Snapshot:1674
# Processing Snapshot:1675
# Processing Snapshot:1676
# Processing Snapshot:1677
# Processing Snapshot:1678
# Processing Snapshot:1679
# Processing Snapshot:1680
# Processing Snapshot:1681
# Processing Snapshot:1682
# Processing Snapshot:1683
# Processing Snapshot:1684
# Processing Snapshot:1685
# Processing Snapshot:1686
# Processing Snapshot:1687
# Processing Snapshot:1688
# Processing Snapshot:1689
# Processing Snapshot:1690
# Processing Snapshot:1691
# Processing Snapshot:1692
# Processing Snapshot:1693
# Processing Snapshot:1694
# Processing Snapshot:1695
# Processing Snapshot:1696
# Processing Snapshot:1697
# Processing Snapshot:1698
# Processing Snapshot:1699
# Processing Snapshot:1700
# Processing Snapshot:1701
# Processing Snapshot:1702
# Processing Snapshot:1703
# Processing Snapshot:1704
# Processing Snapshot:1705
# Processing Snapshot:1706
# Processing Snapshot:1707
# Processing Snapshot:1708
# Processing Snapshot:1709
# Processing Snapshot:1710
# Processing Snapshot:1711
# Processing Snapshot:1712
# Processing Snapshot:1713
# Processing Snapshot:1714
# Processing Snapshot:1715
# Processing Snapshot:1716
# Processing Snapshot:1717
# Processing Snapshot:1718
# Processing Snapshot:1719
# Processing Snapshot:1720
# Processing Snapshot:1721
# Processing Snapshot:1722
# Processing Snapshot:1723
# Processing Snapshot:1724
# Processing Snapshot:1725
# Processing Snapshot:1726
# Processing Snapshot:1727
# Processing Snapshot:1728
# Processing Snapshot:1729
# Processing Snapshot:1730
# Processing Snapshot:1731
# Processing Snapshot:1732
# Processing Snapshot:1733
# Processing Snapshot:1734
# Processing Snapshot:1735
# Processing Snapshot:1736
# Processing Snapshot:1737
# Processing Snapshot:1738
# Processing Snapshot:1739
# Processing Snapshot:1740
# Processing Snapshot:1741
# Processing Snapshot:1742
# Processing Snapshot:1743
# Processing Snapshot:1744
# Processing Snapshot:1745
# Processing Snapshot:1746
# Processing Snapshot:1747
# Processing Snapshot:1748
# Processing Snapshot:1749
# Processing Snapshot:1750
# Processing Snapshot:1751
# Processing Snapshot:1752
# Processing Snapshot:1753
# Processing Snapshot:1754
# Processing Snapshot:1755
# Processing Snapshot:1756
# Processing Snapshot:1757
# Processing Snapshot:1758
# Processing Snapshot:1759
# Processing Snapshot:1760
# Processing Snapshot:1761
# Processing Snapshot:1762
# Processing Snapshot:1763
# Processing Snapshot:1764
# Processing Snapshot:1765
# Processing Snapshot:1766
# Processing Snapshot:1767
# Processing Snapshot:1768
# Processing Snapshot:1769
# Processing Snapshot:1770
# Processing Snapshot:1771
# Processing Snapshot:1772
# Processing Snapshot:1773
# Processing Snapshot:1774
# Processing Snapshot:1775
# Processing Snapshot:1776
# Processing Snapshot:1777
# Processing Snapshot:1778
# Processing Snapshot:1779
# Processing Snapshot:1780
# Processing Snapshot:1781
# Processing Snapshot:1782
# Processing Snapshot:1783
# Processing Snapshot:1784
# Processing Snapshot:1785
# Processing Snapshot:1786
# Processing Snapshot:1787
# Processing Snapshot:1788
# Processing Snapshot:1789
# Processing Snapshot:1790
# Processing Snapshot:1791
# Processing Snapshot:1792
# Processing Snapshot:1793
# Processing Snapshot:1794
# Processing Snapshot:1795
# Processing Snapshot:1796
# Processing Snapshot:1797
# Processing Snapshot:1798
# Processing Snapshot:1799
# Processing Snapshot:1800
# Processing Snapshot:1801
# Processing Snapshot:1802
# Processing Snapshot:1803
# Processing Snapshot:1804
# Processing Snapshot:1805
# Processing Snapshot:1806
# Processing Snapshot:1807
# Processing Snapshot:1808
# Processing Snapshot:1809
# Processing Snapshot:1810
# Processing Snapshot:1811
# Processing Snapshot:1812
# Processing Snapshot:1813
# Processing Snapshot:1814
# Processing Snapshot:1815
# Processing Snapshot:1816
# Processing Snapshot:1817
# Processing Snapshot:1818
# Processing Snapshot:1819
# Processing Snapshot:1820
# Processing Snapshot:1821
# Processing Snapshot:1822
# Processing Snapshot:1823
# Processing Snapshot:1824
# Processing Snapshot:1825
# Processing Snapshot:1826
# Processing Snapshot:1827
# Processing Snapshot:1828
# Processing Snapshot:1829
# Processing Snapshot:1830
# Processing Snapshot:1831
# Processing Snapshot:1832
# Processing Snapshot:1833
# Processing Snapshot:1834
# Processing Snapshot:1835
# Processing Snapshot:1836
# Processing Snapshot:1837
# Processing Snapshot:1838
# Processing Snapshot:1839
# Processing Snapshot:1840
# Processing Snapshot:1841
# Processing Snapshot:1842
# Processing Snapshot:1843
# Processing Snapshot:1844
# Processing Snapshot:1845
# Processing Snapshot:1846
# Processing Snapshot:1847
# Processing Snapshot:1848
# Processing Snapshot:1849
# Processing Snapshot:1850
# Processing Snapshot:1851
# Processing Snapshot:1852
# Processing Snapshot:1853
# Processing Snapshot:1854
# Processing Snapshot:1855
# Processing Snapshot:1856
# Processing Snapshot:1857
# Processing Snapshot:1858
# Processing Snapshot:1859
# Processing Snapshot:1860
# Processing Snapshot:1861
# Processing Snapshot:1862
# Processing Snapshot:1863
# Processing Snapshot:1864
# Processing Snapshot:1865
# Processing Snapshot:1866
# Processing Snapshot:1867
# Processing Snapshot:1868
# Processing Snapshot:1869
# Processing Snapshot:1870
# Processing Snapshot:1871
# Processing Snapshot:1872
# Processing Snapshot:1873
# Processing Snapshot:1874
# Processing Snapshot:1875
# Processing Snapshot:1876
# Processing Snapshot:1877
# Processing Snapshot:1878
# Processing Snapshot:1879
# Processing Snapshot:1880
# Processing Snapshot:1881
# Processing Snapshot:1882
# Processing Snapshot:1883
# Processing Snapshot:1884
# Processing Snapshot:1885
# Processing Snapshot:1886
# Processing Snapshot:1887
# Processing Snapshot:1888
# Processing Snapshot:1889
# Processing Snapshot:1890
# Processing Snapshot:1891
# Processing Snapshot:1892
# Processing Snapshot:1893
# Processing Snapshot:1894
# Processing Snapshot:1895
# Processing Snapshot:1896
# Processing Snapshot:1897
# Processing Snapshot:1898
# Processing Snapshot:1899
# Processing Snapshot:1900
# Processing Snapshot:1901
# Processing Snapshot:1902
# Processing Snapshot:1903
# Processing Snapshot:1904
# Processing Snapshot:1905
# Processing Snapshot:1906
# Processing Snapshot:1907
# Processing Snapshot:1908
# Processing Snapshot:1909
# Processing Snapshot:1910
# Processing Snapshot:1911
# Processing Snapshot:1912
# Processing Snapshot:1913
# Processing Snapshot:1914
# Processing Snapshot:1915
# Processing Snapshot:1916
# Processing Snapshot:1917
# Processing Snapshot:1918
# Processing Snapshot:1919
# Processing Snapshot:1920
# Processing Snapshot:1921
# Processing Snapshot:1922
# Processing Snapshot:1923
# Processing Snapshot:1924
# Processing Snapshot:1925
# Processing Snapshot:1926
# Processing Snapshot:1927
# Processing Snapshot:1928
# Processing Snapshot:1929
# Processing Snapshot:1930
# Processing Snapshot:1931
# Processing Snapshot:1932
# Processing Snapshot:1933
# Processing Snapshot:1934
# Processing Snapshot:1935
# Processing Snapshot:1936
# Processing Snapshot:1937
# Processing Snapshot:1938
# Processing Snapshot:1939
# Processing Snapshot:1940
# Processing Snapshot:1941
# Processing Snapshot:1942
# Processing Snapshot:1943
# Processing Snapshot:1944
# Processing Snapshot:1945
# Processing Snapshot:1946
# Processing Snapshot:1947
# Processing Snapshot:1948
# Processing Snapshot:1949
# Processing Snapshot:1950
# Processing Snapshot:1951
# Processing Snapshot:1952
# Processing Snapshot:1953
# Processing Snapshot:1954
# Processing Snapshot:1955
# Processing Snapshot:1956
# Processing Snapshot:1957
# Processing Snapshot:1958
# Processing Snapshot:1959
# Processing Snapshot:1960
# Processing Snapshot:1961
# Processing Snapshot:1962
# Processing Snapshot:1963
# Processing Snapshot:1964
# ...
# Processing Snapshot:19387
# Processing Snapshot:19388
# Processing Snapshot:19389
# Processing Snapshot:19390
# Processing Snapshot:19391
# Processing Snapshot:19392
# Processing Snapshot:19393
# Processing Snapshot:19394
# Processing Snapshot:19395
# Processing Snapshot:19396
# Processing Snapshot:19397
# Processing Snapshot:19398
# Processing Snapshot:19399
# Processing Snapshot:19400
# Processing Snapshot:19401
# Processing Snapshot:19402
# Processing Snapshot:19403
# Processing Snapshot:19404
# Processing Snapshot:19405
# Processing Snapshot:19406
# Processing Snapshot:19407
# Processing Snapshot:19408
# Processing Snapshot:19409
# Processing Snapshot:19410
# Processing Snapshot:19411
# Processing Snapshot:19412
# Processing Snapshot:19413
# Processing Snapshot:19414
# Processing Snapshot:19415
# Processing Snapshot:19416
# Processing Snapshot:19417
# Processing Snapshot:19418
# Processing Snapshot:19419
# Processing Snapshot:19420
# Processing Snapshot:19421
# Processing Snapshot:19422
# Processing Snapshot:19423
# Processing Snapshot:19424
# Processing Snapshot:19425
# Processing Snapshot:19426
# Processing Snapshot:19427
# Processing Snapshot:19428
# Processing Snapshot:19429
# Processing Snapshot:19430
# Processing Snapshot:19431
# Processing Snapshot:19432
# Processing Snapshot:19433
# Processing Snapshot:19434
# Processing Snapshot:19435
# Processing Snapshot:19436
# Processing Snapshot:19437
# Processing Snapshot:19438
# Processing Snapshot:19439
# Processing Snapshot:19440
# Processing Snapshot:19441
# Processing Snapshot:19442
# Processing Snapshot:19443
# Processing Snapshot:19444
# Processing Snapshot:19445
# Processing Snapshot:19446
# Processing Snapshot:19447
# Processing Snapshot:19448
# Processing Snapshot:19449
# Processing Snapshot:19450
# Processing Snapshot:19451
# Processing Snapshot:19452
# Processing Snapshot:19453
# Processing Snapshot:19454
# Processing Snapshot:19455
# Processing Snapshot:19456
# Processing Snapshot:19457
# Processing Snapshot:19458
# Processing Snapshot:19459
# Processing Snapshot:19460
# Processing Snapshot:19461
# Processing Snapshot:19462
# Processing Snapshot:19463
# Processing Snapshot:19464
# Processing Snapshot:19465
# Processing Snapshot:19466
# Processing Snapshot:19467
# Processing Snapshot:19468
# Processing Snapshot:19469
# Processing Snapshot:19470
# Processing Snapshot:19471
# Processing Snapshot:19472
# Processing Snapshot:19473
# Processing Snapshot:19474
# Processing Snapshot:19475
# Processing Snapshot:19476
# Processing Snapshot:19477
# Processing Snapshot:19478
# Processing Snapshot:19479
# Processing Snapshot:19480
# Processing Snapshot:19481
# Processing Snapshot:19482
# Processing Snapshot:19483
# Processing Snapshot:19484
# Processing Snapshot:19485
# Processing Snapshot:19486
# Processing Snapshot:19487
# Processing Snapshot:19488
# Processing Snapshot:19489
# Processing Snapshot:19490
# Processing Snapshot:19491
# Processing Snapshot:19492
# Processing Snapshot:19493
# Processing Snapshot:19494
# Processing Snapshot:19495
# Processing Snapshot:19496
# Processing Snapshot:19497
# Processing Snapshot:19498
# Processing Snapshot:19499
# Processing Snapshot:19500
# Processing Snapshot:19501
# Processing Snapshot:19502
# Processing Snapshot:19503
# Processing Snapshot:19504
# Processing Snapshot:19505
# Processing Snapshot:19506
# Processing Snapshot:19507
# Processing Snapshot:19508
# Processing Snapshot:19509
# Processing Snapshot:19510
# Processing Snapshot:19511
# Processing Snapshot:19512
# Processing Snapshot:19513
# Processing Snapshot:19514
# Processing Snapshot:19515
# Processing Snapshot:19516
# Processing Snapshot:19517
# Processing Snapshot:19518
# Processing Snapshot:19519
# Processing Snapshot:19520
# Processing Snapshot:19521
# Processing Snapshot:19522
# Processing Snapshot:19523
# Processing Snapshot:19524
# Processing Snapshot:19525
# Processing Snapshot:19526
# Processing Snapshot:19527
# Processing Snapshot:19528
# Processing Snapshot:19529
# Processing Snapshot:19530
# Processing Snapshot:19531
# Processing Snapshot:19532
# Processing Snapshot:19533
# Processing Snapshot:19534
# Processing Snapshot:19535
# Processing Snapshot:19536
# Processing Snapshot:19537
# Processing Snapshot:19538
# Processing Snapshot:19539
# Processing Snapshot:19540
# Processing Snapshot:19541
# Processing Snapshot:19542
# Processing Snapshot:19543
# Processing Snapshot:19544
# Processing Snapshot:19545
# Processing Snapshot:19546
# Processing Snapshot:19547
# Processing Snapshot:19548
# Processing Snapshot:19549
# Processing Snapshot:19550
# Processing Snapshot:19551
# Processing Snapshot:19552
# Processing Snapshot:19553
# Processing Snapshot:19554
# Processing Snapshot:19555
# Processing Snapshot:19556
# Processing Snapshot:19557
# Processing Snapshot:19558
# Processing Snapshot:19559
# Processing Snapshot:19560
# Processing Snapshot:19561
# Processing Snapshot:19562
# Processing Snapshot:19563
# Processing Snapshot:19564
# Processing Snapshot:19565
# Processing Snapshot:19566
# Processing Snapshot:19567
# Processing Snapshot:19568
# Processing Snapshot:19569
# Processing Snapshot:19570
# Processing Snapshot:19571
# Processing Snapshot:19572
# Processing Snapshot:19573
# Processing Snapshot:19574
# Processing Snapshot:19575
# Processing Snapshot:19576
# Processing Snapshot:19577
# Processing Snapshot:19578
# Processing Snapshot:19579
# Processing Snapshot:19580
# Processing Snapshot:19581
# Processing Snapshot:19582
# Processing Snapshot:19583
# Processing Snapshot:19584
# Processing Snapshot:19585
# Processing Snapshot:19586
# Processing Snapshot:19587
# Processing Snapshot:19588
# Processing Snapshot:19589
# Processing Snapshot:19590
# Processing Snapshot:19591
# Processing Snapshot:19592
# Processing Snapshot:19593
# Processing Snapshot:19594
# Processing Snapshot:19595
# Processing Snapshot:19596
# Processing Snapshot:19597
# Processing Snapshot:19598
# Processing Snapshot:19599
# Processing Snapshot:19600
# Processing Snapshot:19601
# Processing Snapshot:19602
# Processing Snapshot:19603
# Processing Snapshot:19604
# Processing Snapshot:19605
# Processing Snapshot:19606
# Processing Snapshot:19607
# Processing Snapshot:19608
# Processing Snapshot:19609
# Processing Snapshot:19610
# Processing Snapshot:19611
# Processing Snapshot:19612
# Processing Snapshot:19613
# Processing Snapshot:19614
# Processing Snapshot:19615
# Processing Snapshot:19616
# Processing Snapshot:19617
# Processing Snapshot:19618
# Processing Snapshot:19619
# Processing Snapshot:19620
# Processing Snapshot:19621
# Processing Snapshot:19622
# Processing Snapshot:19623
# Processing Snapshot:19624
# Processing Snapshot:19625
# Processing Snapshot:19626
# Processing Snapshot:19627
# Processing Snapshot:19628
# Processing Snapshot:19629
# Processing Snapshot:19630
# Processing Snapshot:19631
# Processing Snapshot:19632
# Processing Snapshot:19633
# Processing Snapshot:19634
# Processing Snapshot:19635
# Processing Snapshot:19636
# Processing Snapshot:19637
# Processing Snapshot:19638
# Processing Snapshot:19639
# Processing Snapshot:19640
# Processing Snapshot:19641
# Processing Snapshot:19642
# Processing Snapshot:19643
# Processing Snapshot:19644
# Processing Snapshot:19645
# Processing Snapshot:19646
# Processing Snapshot:19647
# Processing Snapshot:19648
# Processing Snapshot:19649
# Processing Snapshot:19650
# Processing Snapshot:19651
# Processing Snapshot:19652
# Processing Snapshot:19653
# Processing Snapshot:19654
# Processing Snapshot:19655
# Processing Snapshot:19656
# Processing Snapshot:19657
# Processing Snapshot:19658
# Processing Snapshot:19659
# Processing Snapshot:19660
# Processing Snapshot:19661
# Processing Snapshot:19662
# Processing Snapshot:19663
# Processing Snapshot:19664
# Processing Snapshot:19665
# Processing Snapshot:19666
# Processing Snapshot:19667
# Processing Snapshot:19668
# Processing Snapshot:19669
# Processing Snapshot:19670
# Processing Snapshot:19671
# Processing Snapshot:19672
# Processing Snapshot:19673
# Processing Snapshot:19674
# Processing Snapshot:19675
# Processing Snapshot:19676
# Processing Snapshot:19677
# Processing Snapshot:19678
# Processing Snapshot:19679
# Processing Snapshot:19680
# Processing Snapshot:19681
# Processing Snapshot:19682
# Processing Snapshot:19683
# Processing Snapshot:19684
# Processing Snapshot:19685
# Processing Snapshot:19686
# Processing Snapshot:19687
# Processing Snapshot:19688
# Processing Snapshot:19689
# Processing Snapshot:19690
# Processing Snapshot:19691
# Processing Snapshot:19692
# Processing Snapshot:19693
# Processing Snapshot:19694
# Processing Snapshot:19695
# Processing Snapshot:19696
# Processing Snapshot:19697
# Processing Snapshot:19698
# Processing Snapshot:19699
# Processing Snapshot:19700
# Processing Snapshot:19701
# Processing Snapshot:19702
# Processing Snapshot:19703
# Processing Snapshot:19704
# Processing Snapshot:19705
# Processing Snapshot:19706
# Processing Snapshot:19707
# Processing Snapshot:19708
# Processing Snapshot:19709
# Processing Snapshot:19710
# Processing Snapshot:19711
# Processing Snapshot:19712
# Processing Snapshot:19713
# Processing Snapshot:19714
# Processing Snapshot:19715
# Processing Snapshot:19716
# Processing Snapshot:19717
# Processing Snapshot:19718
# Processing Snapshot:19719
# Processing Snapshot:19720
# Processing Snapshot:19721
# Processing Snapshot:19722
# Processing Snapshot:19723
# Processing Snapshot:19724
# Processing Snapshot:19725
# Processing Snapshot:19726
# Processing Snapshot:19727
# Processing Snapshot:19728
# Processing Snapshot:19729
# Processing Snapshot:19730
# Processing Snapshot:19731
# Processing Snapshot:19732
# Processing Snapshot:19733
# Processing Snapshot:19734
# Processing Snapshot:19735
# Processing Snapshot:19736
# Processing Snapshot:19737
# Processing Snapshot:19738
# Processing Snapshot:19739
# Processing Snapshot:19740
# Processing Snapshot:19741
# Processing Snapshot:19742
# Processing Snapshot:19743
# Processing Snapshot:19744
# Processing Snapshot:19745
# Processing Snapshot:19746
# Processing Snapshot:19747
# Processing Snapshot:19748
# Processing Snapshot:19749
# Processing Snapshot:19750
# Processing Snapshot:19751
# Processing Snapshot:19752
# Processing Snapshot:19753
# Processing Snapshot:19754
# Processing Snapshot:19755
# Processing Snapshot:19756
# Processing Snapshot:19757
# Processing Snapshot:19758
# Processing Snapshot:19759
# Processing Snapshot:19760
# Processing Snapshot:19761
# Processing Snapshot:19762
# Processing Snapshot:19763
# Processing Snapshot:19764
# Processing Snapshot:19765
# Processing Snapshot:19766
# Processing Snapshot:19767
# Processing Snapshot:19768
# Processing Snapshot:19769
# Processing Snapshot:19770
# Processing Snapshot:19771
# Processing Snapshot:19772
# Processing Snapshot:19773
# Processing Snapshot:19774
# Processing Snapshot:19775
# Processing Snapshot:19776
# Processing Snapshot:19777
# Processing Snapshot:19778
# Processing Snapshot:19779
# Processing Snapshot:19780
# Processing Snapshot:19781
# Processing Snapshot:19782
# Processing Snapshot:19783
# Processing Snapshot:19784
# Processing Snapshot:19785
# Processing Snapshot:19786
# Processing Snapshot:19787
# Processing Snapshot:19788
# Processing Snapshot:19789
# Processing Snapshot:19790
# Processing Snapshot:19791
# Processing Snapshot:19792
# Processing Snapshot:19793
# Processing Snapshot:19794
# Processing Snapshot:19795
# Processing Snapshot:19796
# Processing Snapshot:19797
# Processing Snapshot:19798
# Processing Snapshot:19799
# Processing Snapshot:19800
# Processing Snapshot:19801
# Processing Snapshot:19802
# Processing Snapshot:19803
# Processing Snapshot:19804
# Processing Snapshot:19805
# Processing Snapshot:19806
# Processing Snapshot:19807
# Processing Snapshot:19808
# Processing Snapshot:19809
# Processing Snapshot:19810
# Processing Snapshot:19811
# Processing Snapshot:19812
# Processing Snapshot:19813
# Processing Snapshot:19814
# Processing Snapshot:19815
# Processing Snapshot:19816
# Processing Snapshot:19817
# Processing Snapshot:19818
# Processing Snapshot:19819
# Processing Snapshot:19820
# Processing Snapshot:19821
# Processing Snapshot:19822
# Processing Snapshot:19823
# Processing Snapshot:19824
# Processing Snapshot:19825
# Processing Snapshot:19826
# Processing Snapshot:19827
# Processing Snapshot:19828
# Processing Snapshot:19829
# Processing Snapshot:19830
# Processing Snapshot:19831
# Processing Snapshot:19832
# Processing Snapshot:19833
# Processing Snapshot:19834
# Processing Snapshot:19835
# Processing Snapshot:19836
# Processing Snapshot:19837
# Processing Snapshot:19838
# Processing Snapshot:19839
# Processing Snapshot:19840
# Processing Snapshot:19841
# Processing Snapshot:19842
# Processing Snapshot:19843
# Processing Snapshot:19844
# Processing Snapshot:19845
# Processing Snapshot:19846
# Processing Snapshot:19847
# Processing Snapshot:19848
# Processing Snapshot:19849
# Processing Snapshot:19850
# Processing Snapshot:19851
# Processing Snapshot:19852
# Processing Snapshot:19853
# Processing Snapshot:19854
# Processing Snapshot:19855
# Processing Snapshot:19856
# Processing Snapshot:19857
# Processing Snapshot:19858
# Processing Snapshot:19859
# Processing Snapshot:19860
# Processing Snapshot:19861
# Processing Snapshot:19862
# Processing Snapshot:19863
# Processing Snapshot:19864
# Processing Snapshot:19865
# Processing Snapshot:19866
# Processing Snapshot:19867
# Processing Snapshot:19868
# Processing Snapshot:19869
# Processing Snapshot:19870
# Processing Snapshot:19871
# Processing Snapshot:19872
# Processing Snapshot:19873
# Processing Snapshot:19874
# Processing Snapshot:19875
# Processing Snapshot:19876
# Processing Snapshot:19877
# Processing Snapshot:19878
# Processing Snapshot:19879
# Processing Snapshot:19880
# Processing Snapshot:19881
# Processing Snapshot:19882
# Processing Snapshot:19883
# Processing Snapshot:19884
# Processing Snapshot:19885
# Processing Snapshot:19886
# Processing Snapshot:19887
# Processing Snapshot:19888
# Processing Snapshot:19889
# Processing Snapshot:19890
# Processing Snapshot:19891
# Processing Snapshot:19892
# Processing Snapshot:19893
# Processing Snapshot:19894
# Processing Snapshot:19895
# Processing Snapshot:19896
# Processing Snapshot:19897
# Processing Snapshot:19898
# Processing Snapshot:19899
# Processing Snapshot:19900
# Processing Snapshot:19901
# Processing Snapshot:19902
# Processing Snapshot:19903
# Processing Snapshot:19904
# Processing Snapshot:19905
# Processing Snapshot:19906
# Processing Snapshot:19907
# Processing Snapshot:19908
# Processing Snapshot:19909
# Processing Snapshot:19910
# Processing Snapshot:19911
# Processing Snapshot:19912
# Processing Snapshot:19913
# Processing Snapshot:19914
# Processing Snapshot:19915
# Processing Snapshot:19916
# Processing Snapshot:19917
# Processing Snapshot:19918
# Processing Snapshot:19919
# Processing Snapshot:19920
# Processing Snapshot:19921
# Processing Snapshot:19922
# Processing Snapshot:19923
# Processing Snapshot:19924
# Processing Snapshot:19925
# Processing Snapshot:19926
# Processing Snapshot:19927
# Processing Snapshot:19928
# Processing Snapshot:19929
# Processing Snapshot:19930
# Processing Snapshot:19931
# Processing Snapshot:19932
# Processing Snapshot:19933
# Processing Snapshot:19934
# Processing Snapshot:19935
# Processing Snapshot:19936
# Processing Snapshot:19937
# Processing Snapshot:19938
# Processing Snapshot:19939
# Processing Snapshot:19940
# Processing Snapshot:19941
# Processing Snapshot:19942
# Processing Snapshot:19943
# Processing Snapshot:19944
# Processing Snapshot:19945
# Processing Snapshot:19946
# Processing Snapshot:19947
# Processing Snapshot:19948
# Processing Snapshot:19949
# Processing Snapshot:19950
# Processing Snapshot:19951
# Processing Snapshot:19952
# Processing Snapshot:19953
# Processing Snapshot:19954
# Processing Snapshot:19955
# Processing Snapshot:19956
# Processing Snapshot:19957
# Processing Snapshot:19958
# Processing Snapshot:19959
# Processing Snapshot:19960
# Processing Snapshot:19961
# Processing Snapshot:19962
# Processing Snapshot:19963
# Processing Snapshot:19964
# Processing Snapshot:19965
# Processing Snapshot:19966
# Processing Snapshot:19967
# Processing Snapshot:19968
# Processing Snapshot:19969
# Processing Snapshot:19970
# Processing Snapshot:19971
# Processing Snapshot:19972
# Processing Snapshot:19973
# Processing Snapshot:19974
# Processing Snapshot:19975
# Processing Snapshot:19976
# Processing Snapshot:19977
# Processing Snapshot:19978
# Processing Snapshot:19979
# Processing Snapshot:19980
# Processing Snapshot:19981
# Processing Snapshot:19982
# Processing Snapshot:19983
# Processing Snapshot:19984
# Processing Snapshot:19985
# Processing Snapshot:19986
# Processing Snapshot:19987
# Processing Snapshot:19988
# Processing Snapshot:19989
# Processing Snapshot:19990
# Processing Snapshot:19991
# Processing Snapshot:19992
# Processing Snapshot:19993
# Processing Snapshot:19994
# Processing Snapshot:19995
# Processing Snapshot:19996
# Processing Snapshot:19997
# Processing Snapshot:19998
# Processing Snapshot:19999
# Processing Snapshot:20000
# Processing Snapshot:20001

# %%
#traj.s1, traj.s2 = traj.split_species()
traj.indexlist, dist_1 = traj.get_neighbour_KDT(mode='pbc', snapshot=0)
#traj.get_ion_distance()
# Out:
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead

# %%
traj.get_ion_distance()
# Out:
# array([[0.00000000e+00, 3.51310000e-01, 4.18493000e-01, ...,
#         2.94348000e-01, 4.90757000e-01, 1.72361912e-01],
#        [1.00000000e+00, 3.51341000e-01, 4.18551000e-01, ...,
#         2.94351000e-01, 4.90721000e-01, 1.72294335e-01],
#        [2.00000000e+00, 3.51415000e-01, 4.18312000e-01, ...,
#         2.94390000e-01, 4.90488000e-01, 1.71872013e-01],
#        ...,
#        [1.99980000e+04, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.99990000e+04, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.00000000e+04, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
generate_md_input(folder_input='/home/ibrahimk95/pythoncodes/trajectories_for_new_NN_testing/water/', folder_output='/home/ibrahimk95/pythoncodes/trajectories_for_new_NN_testing/ions/', N_traj=20, is_scaled=0)
# Out:
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.75315565, 16.83024436],
#        [ 0.75315565, 16.83024436],
#        [ 0.75315565, 16.83024436]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.32127730809182753
# distance too far next O
# 0.5194562408523818
# distance too far next O
# 0.42039627687758874
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.68582897, 16.89757104],
#        [ 0.68582897, 16.89757104],
#        [ 0.68582897, 16.89757104]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.543630701102364
# distance too far next O
# 0.5953410921684442
# distance too far next O
# 0.42941862205258685
# distance too far next O
# 0.5061194427996764
# distance too far next O
# 0.24086112703459833
# distance too far next O
# 0.3851029783503363
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.69117811, 16.8922219 ],
#        [ 0.69117811, 16.8922219 ],
#        [ 0.69117811, 16.8922219 ]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.43654776458452493
# distance too far next O
# 0.4462541631715204
# distance too far next O
# 0.5245737731550143
# distance too far next O
# 0.625074554969952
# distance too far next O
# 0.2710244196527312
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.84196924, 16.74143077],
#        [ 0.84196924, 16.74143077],
#        [ 0.84196924, 16.74143077]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.49281491963243285
# distance too far next O
# 0.2848042482539123
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.61530246, 16.96809756],
#        [ 0.61530246, 16.96809756],
#        [ 0.61530246, 16.96809756]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.5853958863109499
# distance too far next O
# 0.5196177018562611
# distance too far next O
# 0.482010913716351
# distance too far next O
# 0.4042639072505671
# distance too far next O
# 0.40382337688934955
# distance too far next O
# 0.5027237116282762
# distance too far next O
# 0.5801197568263751
# distance too far next O
# 0.32292054194291187
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.65435066, 16.92904936],
#        [ 0.65435066, 16.92904936],
#        [ 0.65435066, 16.92904936]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.528486990714185
# distance too far next O
# 0.5795136702702591
# distance too far next O
# 0.4540761508348677
# distance too far next O
# 0.6065761982597644
# distance too far next O
# 0.4951825506204056
# distance too far next O
# 0.6446446291921927
# distance too far next O
# 0.5567217579336368
# distance too far next O
# 0.46188365603763915
# distance too far next O
# 0.5594951747383522
# distance too far next O
# 0.6244833754894333
# distance too far next O
# 0.6042657830313352
# distance too far next O
# 0.4767131497098218
# distance too far next O
# 0.4602813418961804
# distance too far next O
# 0.3989656462604232
# distance too far next O
# 0.43732480755331743
# distance too far next O
# 0.6602230666648057
# distance too far next O
# 0.4812938746525288
# distance too far next O
# 0.6092548465367147
# distance too far next O
# 0.46315162979857516
# distance too far next O
# 0.6471410217556764
# distance too far next O
# 0.7130022019193342
# distance too far next O
# 0.6257954415546777
# distance too far next O
# 0.5553078152636908
# distance too far next O
# 0.8063054785457876
# distance too far next O
# 0.4993505218361725
# distance too far next O
# 0.7754646303183295
# distance too far next O
# 0.719790219238289
# distance too far next O
# 0.6551573439094686
# distance too far next O
# 0.6441582740069832
# distance too far next O
# 0.7359932603233991
# distance too far next O
# 0.7133005944936764
# distance too far next O
# 0.463244705829061
# distance too far next O
# 0.47230370886541334
# distance too far next O
# 0.5236607609143497
# distance too far next O
# 0.38234027773678486
# distance too far next O
# 0.3844208372110836
# distance too far next O
# 0.3061672509672738
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.76853707, 16.81486294],
#        [ 0.76853707, 16.81486294],
#        [ 0.76853707, 16.81486294]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.5345738553777803
# distance too far next O
# 0.46163535540585354
# distance too far next O
# 0.4129609202032707
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.75315565, 16.83024436],
#        [ 0.75315565, 16.83024436],
#        [ 0.75315565, 16.83024436]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.47126373147304385
# distance too far next O
# 0.341019543235897
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.76853707, 16.81486294],
#        [ 0.76853707, 16.81486294],
#        [ 0.76853707, 16.81486294]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.5038514022173486
# distance too far next O
# 0.44679580952693054
# distance too far next O
# 0.4839134923304095
# distance too far next O
# 0.5459746756943182
# distance too far next O
# 0.3864848806318595
# distance too far next O
# 0.4902737085666219
# distance too far next O
# 0.42702423229395464
# distance too far next O
# 0.3549155078533797
# distance too far next O
# 0.40054484900915294
# distance too far next O
# 0.5079199528239388
# distance too far next O
# 0.4575901896971233
# distance too far next O
# 0.30239568010262097
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.65992022, 16.92347979],
#        [ 0.65992022, 16.92347979],
#        [ 0.65992022, 16.92347979]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.6408555676449076
# distance too far next O
# 0.47147795740308956
# distance too far next O
# 0.46679148441572793
# distance too far next O
# 0.5372375831112018
# distance too far next O
# 0.5941879567422292
# distance too far next O
# 0.5974979908077767
# distance too far next O
# 0.41021397371792717
# distance too far next O
# 0.2928862481132378
# distance too far next O
# 0.5147940069110819
# distance too far next O
# 0.44204652675319867
# distance too far next O
# 0.41916831560027334
# distance too far next O
# 0.6447638902088267
# distance too far next O
# 0.4602144715612791
# distance too far next O
# 0.5725712721034745
# distance too far next O
# 0.5025024576337169
# distance too far next O
# 0.6693811988918301
# distance too far next O
# 0.6542702820762746
# distance too far next O
# 0.5703265676428761
# distance too far next O
# 0.5482389863787439
# distance too far next O
# 0.44628207274657383
# distance too far next O
# 0.5113993737249711
# distance too far next O
# 0.42623419215552316
# distance too far next O
# 0.41076336954774234
# distance too far next O
# 0.4189508068032812
# distance too far next O
# 0.39643035670471777
# distance too far next O
# 0.3465465526061439
# distance too far next O
# 0.4970991889962361
# distance too far next O
# 0.5080118907253746
# distance too far next O
# 0.5199683004028011
# distance too far next O
# 0.4098422377350813
# distance too far next O
# 0.3644851685754067
# distance too far next O
# 0.602135497812814
# distance too far next O
# 0.6889684248512882
# distance too far next O
# 0.6715991629212803
# distance too far next O
# 0.4804562102483062
# distance too far next O
# 0.7344133242964633
# distance too far next O
# 0.5950598672105688
# distance too far next O
# 0.5823342715338239
# distance too far next O
# 0.81381483615646
# distance too far next O
# 0.5976529867593438
# distance too far next O
# 0.7031606428816943
# distance too far next O
# 0.6079307774285405
# distance too far next O
# 0.72394883089018
# distance too far next O
# 0.5858370353753981
# distance too far next O
# 0.6908832084097238
# distance too far next O
# 0.641741998112197
# distance too far next O
# 0.6205682161444729
# distance too far next O
# 0.711092011456205
# distance too far next O
# 0.5469920893559606
# distance too far next O
# 0.6517867664575124
# distance too far next O
# 0.4626178706496673
# distance too far next O
# 0.5072118631914284
# distance too far next O
# 0.6387253753772568
# distance too far next O
# 0.45168420601954495
# distance too far next O
# 0.6169694946380371
# distance too far next O
# 0.6668530193839333
# distance too far next O
# 0.43338570913288305
# distance too far next O
# 0.6311433478710045
# distance too far next O
# 0.6060319681678435
# distance too far next O
# 0.4878814545208169
# distance too far next O
# 0.5604259409674782
# distance too far next O
# 0.4662567097564997
# distance too far next O
# 0.6946603954738206
# distance too far next O
# 0.37298551941631114
# distance too far next O
# 0.6277202880470029
# distance too far next O
# 0.17201323655055065
# distance too far next O
# 0.3931310420206797
# distance too far next O
# 0.43064047258929505
# distance too far next O
# 0.5402549648964894
# distance too far next O
# 0.49784962577098096
# distance too far next O
# 0.2761959423382378
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.68582897, 16.89757104],
#        [ 0.68582897, 16.89757104],
#        [ 0.68582897, 16.89757104]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.40916335500367546
# distance too far next O
# 0.3514019749876085
# distance too far next O
# 0.5374697867954878
# distance too far next O
# 0.6437187956240707
# distance too far next O
# 0.7217166219030655
# distance too far next O
# 0.7472589340671306
# distance too far next O
# 0.623450200709411
# distance too far next O
# 0.5349232578525763
# distance too far next O
# 0.4463784405383584
# distance too far next O
# 0.5779770210732615
# distance too far next O
# 0.6812921470444582
# distance too far next O
# 0.5777163664107083
# distance too far next O
# 0.4247942578495854
# distance too far next O
# 0.5211113352407426
# distance too far next O
# 0.5347992660864525
# distance too far next O
# 0.4353802844194646
# distance too far next O
# 0.6061704563229423
# distance too far next O
# 0.6176201162642407
# distance too far next O
# 0.47542150005228107
# distance too far next O
# 0.5155391064134032
# distance too far next O
# 0.6710330820400987
# distance too far next O
# 0.6033216642452581
# distance too far next O
# 0.5144283419574152
# distance too far next O
# 0.6513566878502315
# distance too far next O
# 0.3386726105720698
# distance too far next O
# 0.6863265820513494
# distance too far next O
# 0.6675879526768691
# distance too far next O
# 0.4157974489397161
# distance too far next O
# 0.6238683355431425
# distance too far next O
# 0.589610743453164
# distance too far next O
# 0.4495547584170294
# distance too far next O
# 0.7602691964072967
# distance too far next O
# 0.22474083234276104
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.65873803, 16.92466199],
#        [ 0.65873803, 16.92466199],
#        [ 0.65873803, 16.92466199]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.420558326355505
# distance too far next O
# 0.4695020197190494
# distance too far next O
# 0.5496194507722761
# distance too far next O
# 0.36824449590863045
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.75315565, 16.83024436],
#        [ 0.75315565, 16.83024436],
#        [ 0.75315565, 16.83024436]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.34085193903363714
# distance too far next O
# 0.46999037147722883
# distance too far next O
# 0.5206824916654705
# distance too far next O
# 0.6337320419510896
# distance too far next O
# 0.7307844838318414
# distance too far next O
# 0.5858375917929163
# distance too far next O
# 0.24223900321207875
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.56101153, 17.02238849],
#        [ 0.56101153, 17.02238849],
#        [ 0.56101153, 17.02238849]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.5749317409651459
# distance too far next O
# 0.5391508067136122
# distance too far next O
# 0.43294007671484386
# distance too far next O
# 0.2931187769743007
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.69117811, 16.8922219 ],
#        [ 0.69117811, 16.8922219 ],
#        [ 0.69117811, 16.8922219 ]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.49269244038423443
# distance too far next O
# 0.5880474178417658
# distance too far next O
# 0.4803927444987016
# distance too far next O
# 0.5847694319756036
# distance too far next O
# 0.5421091150727698
# distance too far next O
# 0.672808173221561
# distance too far next O
# 0.5727844062864527
# distance too far next O
# 0.6883462717664773
# distance too far next O
# 0.4798292465314989
# distance too far next O
# 0.636815388784891
# distance too far next O
# 0.6080557740418232
# distance too far next O
# 0.5162762627249151
# distance too far next O
# 0.662571299739465
# distance too far next O
# 0.6402992661164005
# distance too far next O
# 0.464996688908258
# distance too far next O
# 0.3118881220380142
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.68582897, 16.89757104],
#        [ 0.68582897, 16.89757104],
#        [ 0.68582897, 16.89757104]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.3974105083173154
# distance too far next O
# 0.5294655886254205
# distance too far next O
# 0.4954365687850332
# distance too far next O
# 0.505937347788318
# distance too far next O
# 0.3983386925754168
# distance too far next O
# 0.49026511740473816
# distance too far next O
# 0.5046337247878456
# distance too far next O
# 0.5865994949861139
# distance too far next O
# 0.61818778274756
# distance too far next O
# 0.31746667733214784
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.61530246, 16.96809756],
#        [ 0.61530246, 16.96809756],
#        [ 0.61530246, 16.96809756]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.4126675642384367
# distance too far next O
# 0.5645313530714483
# distance too far next O
# 0.5961767586610497
# distance too far next O
# 0.5393351608887409
# distance too far next O
# 0.3744828290052542
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.65873803, 16.92466199],
#        [ 0.65873803, 16.92466199],
#        [ 0.65873803, 16.92466199]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.2255054277505187
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.73453511, 16.8488649 ],
#        [ 0.73453511, 16.8488649 ],
#        [ 0.73453511, 16.8488649 ]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.6304295287055673
# distance too far next O
# 0.41294926108291385
# distance too far next O
# 0.4035483918149097
# distance too far next O
# 0.35542242991846035
# distance too far next O
# 0.4055030958482768
# distance too far next O
# 0.37832303522792604
# distance too far next O
# 0.4959027343818023
# distance too far next O
# 0.5627262740338788
# distance too far next O
# 0.42474078182053937
# distance too far next O
# 0.4790814090523297
# distance too far next O
# 0.55902056232543
# distance too far next O
# 0.41821570946072206
# distance too far next O
# 0.40084598086547557
# distance too far next O
# 0.4834290419247989
# distance too far next O
# 0.3409351198556427
# displace
# trajectory saved as water.data
# 384 atoms
#
# [384]
# (1, 384, 5)
# [array([[ 0.56101153, 17.02238849],
#        [ 0.56101153, 17.02238849],
#        [ 0.56101153, 17.02238849]])]
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# 0.6371186608510722
# distance too far next O
# 0.5485436810627167
# distance too far next O
# 0.5587427302968634
# distance too far next O
# 0.3696289277955083
# distance too far next O
# 0.35141317019780854
# distance too far next O
# 0.6227155772219496
# distance too far next O
# 0.40952218832058146
# distance too far next O
# 0.379605698328586
# distance too far next O
# 0.5945760104249718
# distance too far next O
# 0.526732497452658
# distance too far next O
# 0.684516246712499
# distance too far next O
# 0.49577768109405873
# distance too far next O
# 0.18191117063649426
# displace
# trajectory saved as water.data

# %%
traj.get_displace(snapshot = 0, id = None, distance=0.44, eps=0.05, dp_factor = 0.99)#, path="/home/ibrahimk95/pythoncodes/ab_initio_initials_n384/")
# Out:
# 0.4431758140817253
# displace
# trajectory saved as water.data

# %%
traj.cut_snapshot(snapshot=0)

# %%
rmsd = traj.get_radial_diffusion(timestep=(traj.n_snapshots*0.0005))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 rmsd = traj.get_radial_diffusion(timestep=(traj.n_snapshots*0.0005))
#
# Input In [42], in Trajectory.get_radial_diffusion(self, timestep)
#    1265 for O_atom in  range(self.s2[0].shape[0]):
#    1267     H_1 = atom_id_H[np.argwhere(indexlist_group == O_atom)[0]][0]
# -> 1268     H_2 = atom_id_H[np.argwhere(indexlist_group == O_atom)[1]][0]
#    1269     O = atom_id_O[O_atom]
#    1271     molecule_list[O_atom] = (H_1, H_2, O)
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
traj.plot_d_rot(rmsd, timestep=(traj.n_snapshots*0.0005))

# %%
fig, ax = plt.subplots()

ax.scatter(0.0005*1000*np.linspace(0,len(rmsd), len(rmsd)), rmsd, color="red", marker="x")
ax.plot(0.0005*1000*np.linspace(0,len(rmsd), len(rmsd)), rmsd)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))
ax.xaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))
ax.set_xlabel("$\Delta$t in ps")
ax.grid()
ax.set_ylabel("<$\phi^2(\Delta t)$>")
ax.set_title("Rotational Diffusion")

plt.yscale("log")
plt.xscale("log")
plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(0.0005*1000*np.linspace(0,len(rmsd), len(rmsd)), rmsd, color="red", marker="x")
ax.plot(0.0005*1000*np.linspace(0,len(rmsd), len(rmsd)), rmsd)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))
ax.xaxis.set_major_formatter(mtick.FormatStrFormatter('%.1e'))
ax.set_xlabel("$\Delta$t in ps")
ax.grid()
ax.set_ylabel("<$\phi^2(\Delta t)$>")
ax.set_title("Rotational Diffusion")

plt.show()

# %%
traj2 = Trajectory("reduced_water.lammpstrj")
traj2.get_box_size()
traj2.s1, traj2.s2 = traj2.split_species()
print(traj2.s1)
# Out:
# Processing Snapshot:1
# [array([[5.92600e+03, 1.00000e+00, 1.70260e-01, 2.87872e-01, 3.48330e-02],
#        [1.16020e+04, 1.00000e+00, 1.25171e-01, 4.25715e-01, 2.22317e-01],
#        [1.03470e+04, 1.00000e+00, 9.17387e-03, 4.11117e-01, 9.73607e-01],
#        ...,
#        [3.60300e+03, 1.00000e+00, 9.48402e-01, 5.29586e-01, 5.46967e-01],
#        [3.60200e+03, 1.00000e+00, 9.20487e-01, 5.25505e-01, 5.50430e-01],
#        [2.98300e+03, 1.00000e+00, 8.75902e-01, 5.02455e-01, 6.35631e-01]])]

# %%
traj2.indexlist, _ = traj2.get_neighbour_KDT(mode="pbc")
# Out:
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead

# %%
traj2.get_displace(snapshot = 0, id = None, distance=0.5, eps=0.01, dp_factor = 0.99,
                     path=None, num_traj=None)
# Out:
# 0.37333755555796955
# distance too far next O
# 0.5706349544963049
# distance too far next O
# 0.6039576722360931
# distance too far next O
# 0.6157085454378963
# distance too far next O
# 0.4741110273269332
# distance too far next O
# 0.4269542310623001
# distance too far next O
# 0.5898473724265032
# distance too far next O
# 0.3018054030762206
# distance too far next O
# 0.3816345303742837
# distance too far next O
# 0.2249826956017951
# distance too far next O
# 0.4943871787708496
# displace
# trajectory saved as water.data

# %%
traj.group_molecules(path="/home/ibrahimk95/Documents/n2p2_sims/working_files/new_ion_NN/recombination_5/")
# Out:
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# ...
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead

# %%
traj.get_ion_distance()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 traj.get_ion_distance()
#
# Input In [21], in Trajectory.get_ion_distance(self)
#     560     if OH_id is None or H3O_id is None:
#     561         raise ValueError("Either OH or H3O index was not found")
# --> 564     temp = get_distance(self.trajectory[i, OH_id, 2:], self.trajectory[i, H3O_id, 2:])
#     566     self.ion_distance[i, :] = np.array([i] + self.trajectory[i, OH_id, 2:].tolist() \
#     567                                           + self.trajectory[i, H3O_id, 2:].tolist() + [temp])
#     568 ##TODO: TESTING
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
traj.remove_atoms(N=126)
#def remove_atoms(self, N=1, snap=0, atom_id=None, format_out="lammps"):
# Out:
# (128, 5) (256, 5)
# Atribute Error occured(recieved list instead of numpy array) using first element of list instead
# (2, 5) (4, 5)
